# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
data = pd.read_csv("data/Breast_cancer_data.csv")
data.head()
# Out:
#    mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    diagnosis
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
data["diagnosis"].hist()
# Out:
# <Axes: >

# %%
corr = data.iloc[:, :-1].corr(method="pearson")
cmap = sns.diverging_palette(250, 354, 80, 60, center="dark", as_cmap=True)
sns.heatmap(corr, vmax=1, vmin=.5, cmap=cmap, square=True, linewidths=.2)
# Out:
# <Axes: >

# %%
data = data[["mean_radius", "mean_texture", "mean_smoothness", "diagnosis"]]
data.head()
# Out:
#    mean_radius  mean_texture  mean_smoothness  diagnosis
# 0        17.99         10.38          0.11840          0
# 1        20.57         17.77          0.08474          0
# 2        19.69         21.25          0.10960          0
# 3        11.42         20.38          0.14250          0
# 4        20.29         14.34          0.10030          0

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)
sns.histplot(data, ax=axes[0], x="mean_radius", kde=True, color='r')
sns.histplot(data, ax=axes[1], x="mean_smoothness", kde=True, color='b')
sns.histplot(data, ax=axes[2], x="mean_texture", kde=True, color='g')
# Out:
# <Axes: xlabel='mean_texture', ylabel='Count'>

# %% [markdown]
# ## Calculate P(Y=y) for all possible y

# %%
def calculate_prior(df, Y):
    classes = sorted(list(df[Y].unique()))
    prior = []
    for i in classmethod:
        prior.append(len(df[df[Y]==i]))/ len(df)
    return prior

# %% [markdown]
# ## Approach 1: Calculate P(X = x | Y = y) using Gaussian dist.

# %%
def calculate_likelihood_gaussian(df, feature_name, feature_val, Y, label):
    """
    Given feature name and feature value returns the probability of x given label
    """
    feature = list(df.columns)
    df = df[df[Y] == label]
    mean, std = df[feature_name].mean(), df[feature_name].std()
    p_x_given_y = ( 1 / (np.sqrt(2 * np.pi) * std)) * np.exp(-((feature_val-mean)**2 / (2 * std**2)))
    return p_x_given_y

# %%
## Calculate P(X=x2|Y=y)P(X=x2|Y=y)...... * P(Y=y) for all y and find

# %%
for a in data["diagnosis"].unique():
    print(a)
# Out:
# 0
# 1

# %%
class NaiveBayes(object):
    def __init__(self):
         self.y_probs = {}
         self.x_probs = {}

    def fit(self,
            X,
            Y):
        pass

    def __calculate_probs(self,
                          X,
                          Y):
            self.feature_names = list(X.columns)

            # Calculating P(Y)
            self.classes = Y.unique() # numpy array

            for label in self.classes:
                 self.y_probs[label] = len(Y[Y == label])/ len(Y)

            # Calculating
