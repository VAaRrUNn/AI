# %%
import torch 
import torch.nn as nn
import torch.optim as optim
import spacy
import torch.nn.functional as F
from tqdm.auto import tqdm
import torch.utils.tensorboard 
from torchtext.datasets import Multi30k
import unicodedata
from torchtext.data import Field, BucketIterator

# %% [markdown]
# ## Building Vocabulary

# %%
es = 0x090
ee = 0x005A 
combinations = list("0123456789ABCDEF")

hindi_vocab = []
for codepoint in range(0x900, 0x980):
    character = chr(codepoint)
    hindi_vocab.append(character)

# %%
len(hindi_vocab)
# Out:
# 128

# %%
# START_TOKEN = ''
# PADDING_TOKEN = ''
# END_TOKEN = ''
START_TOKEN = '+'
PADDING_TOKEN = '-'
END_TOKEN = '_'

# hindi_vocab_start = 0x0900
# hindi_vocab_end = 0x097F

english_vocab_start = 0x0041
english_vocab_end = 0x005A

# hindi_vocab = [chr(code) for code in range(hindi_vocab_start, hindi_vocab_end + 1)
#                    if 'L' in unicodedata.category(chr(code))]

english_vocab = [chr(code) for code in range(english_vocab_start, english_vocab_end + 1) 
                   if 'L' in unicodedata.category(chr(code))]


## For lower case alphabets
english_vocab_start = 0x0061
english_vocab_end = 0x007A

english_vocab2 = [chr(code) for code in range(english_vocab_start, english_vocab_end + 1) 
                   if 'L' in unicodedata.category(chr(code))]

english_vocab += english_vocab2

hindi_vocab.insert(0, START_TOKEN)
english_vocab.insert(0, START_TOKEN)

english_vocab.extend(list(",.!`:;"))
english_vocab.extend(list("0123456789@#$%^&*()"))
# english_vocab.append('"')
english_vocab.append(' ')
english_vocab.append("'")

hindi_vocab.append("'")
hindi_vocab.append(" ")
# hindi_vocab.append('"')
hindi_vocab.append(',')
hindi_vocab.append('.')

hindi_vocab.insert(0, PADDING_TOKEN)
english_vocab.insert(0, PADDING_TOKEN)

hindi_vocab.insert(0, END_TOKEN)
english_vocab.insert(0, END_TOKEN)

# Print the Hindi alphabets
len(english_vocab), len(hindi_vocab)
# Out:
# (82, 135)

# %%
index_to_hindi = {k:v for k, v in enumerate(hindi_vocab)}
index_to_english = {k:v for k, v in enumerate(english_vocab)}

hindi_to_index = {v:k for k, v in enumerate(hindi_vocab)}
english_to_index = {v:k for k, v in enumerate(english_vocab)}

print(len(index_to_hindi), len(hindi_to_index))
print(len(index_to_english), len(english_to_index))
# Out:
# 135 135
# 82 82

# %%
import os

with open("dataset/Hindi_English_Truncated_Corpus.csv", 'r') as f:
    l = f.readlines()

# %%
full_sentense = l[2].split(',', 1)[1].strip('\n"')
full_sentense
for i in range(len(full_sentense)):
    if full_sentense[i] in hindi_vocab:
        print(f"We got {full_sentense[i]} at {i}")
        break
full_sentense[:45], full_sentense[45:]
# Out:
# We got ' at 1
# ('I\'d like to tell you about one such child,","',
#  'मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहूंगी,')

# %%
dataset_path = "dataset/Hindi_English_Truncated_Corpus.csv"

def get_first_index(sentence, vocab, vocab2):
    for i in range(len(sentence)):
        if sentence[i] in vocab and sentence[i] != " " and sentence[i] not in vocab2:
            return i
    return -1

def get_dataset():
    with open(dataset_path, 'r') as f:
        lines = f.readlines()
    english_sentences, hindi_sentences = [], []
    # Skipping first line cause it's header
    # i = 0
    for a in range(1, len(lines)):
        # print(f"lines -> {lines[a]}")
        line = lines[a].split(',', 1)[1].strip('\n"')
        # print(f"after -> {line}")
        index = get_first_index(line, hindi_vocab, english_vocab)
        if index == -1:
            continue
        eng = line[:index].strip('",?')
        hin = line[index:].strip('",.!_`?')
        # print(f"eng -> {eng}")
        # print(f"hin -> {hin}\n")
        english_sentences.append(eng)
        hindi_sentences.append(hin)
        # if i== 3:
        #     break
        # i+= 1
    
    return english_sentences, hindi_sentences

english_sentences, hindi_sentences = get_dataset()

# %%
english_sentences[:4], hindi_sentences[:5]
# Out:
# (['politicians do not have permission to do what needs to be done.',
#   "I'd like to tell you about one such child",
#   'This percentage is even greater than the percentage in India.',
#   "what we really mean is that they're bad at not paying attention."],
#  ['राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह करने कि अनुमति नहीं है ',
#   'मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहूंगी',
#   'यह प्रतिशत भारत में हिन्दुओं प्रतिशत से अधिक है।',
#   'हम ये नहीं कहना चाहते कि वो ध्यान नहीं दे पाते',
#   'इन्हीं वेदों का अंतिम भाग उपनिषद कहलाता है।'])

# %%
import numpy as np
PERCENTILE = 97
print( f"{PERCENTILE}th percentile length Kannada: {np.percentile([len(x) for x in english_sentences], PERCENTILE)}" )
print( f"{PERCENTILE}th percentile length English: {np.percentile([len(x) for x in hindi_sentences], PERCENTILE)}" )
# Out:
# 97th percentile length Kannada: 267.0
# 97th percentile length English: 265.0

# %% [markdown]
# ## Need to account for vowels and other thing like आ and 'ा are same but aren't in the vocab

# %%
MAX_SEQUENCE_LENGTH = 300
def is_valid_token(sentence, vocab):
    # for token in list(set(sentence)):
    for token in sentence:
        if token not in vocab:
            return False
    return True
    
    
def is_valid_length(sentence, max_sequence_length):
    return len(list(sentence)) < (max_sequence_length - 1)

valid_sentence_indices = []
for index in range(len(hindi_sentences)):
    hindi_sentence, english_sentence = hindi_sentences[index], english_sentences[index]
    if is_valid_length(hindi_sentence, MAX_SEQUENCE_LENGTH) \
        and is_valid_token(hindi_sentence, hindi_vocab) \
        and is_valid_token(english_sentence, english_vocab) \
        and is_valid_length(english_sentence, MAX_SEQUENCE_LENGTH):
        valid_sentence_indices.append(index)

print(f"Number of sentences in Hindi: {len(hindi_sentences)}")
print(f"Number of sentences in English: {len(english_sentences)}")
print(f"Number of valid sentences: {len(valid_sentence_indices)}")
valid_sentence_indices[:5]
# Out:
# Number of sentences in Hindi: 127575
# Number of sentences in English: 127575
# Number of valid sentences: 90289
# [0, 1, 2, 3, 4]

# %% [markdown]
# ## For now compromising...

# %%
def is_valid_token(sentence, vocab):
    # for token in list(set(sentence)):
    for token in sentence:
        if token not in vocab:
            print(f"is this space{token}yeah")
            print("huh")
            return False
    return True

is_valid_token(hindi_sentences[0], hindi_vocab),
# Out:
# (True,)

# %%
english_sentences
# Out:
# ['politicians do not have permission to do what needs to be done.',
#  "I'd like to tell you about one such child",
#  'This percentage is even greater than the percentage in India.',
#  "what we really mean is that they're bad at not paying attention.",
#  '.The ending portion of these Vedas is called Upanishad.',
#  'The then Governor of Kashmir resisted transfer , but was finally reduced to subjection with the aid of British .',
#  'In this lies the circumstances of people before you.',
#  'And who are we to say, even, that they are wrong',
#  '“”Global Warming“” refer to warming caused in recent decades and probability of its continual presence and its indirect effect on human being.',
#  "You may want your child to go to a school that is not run by the LEA - a non-maintained special school or an independent school that can meet your child 's needs .",
#  'Please ensure that you use the appropriate form .',
#  'Category: Religious Text',
#  'This period summarily is pepped up with devotion.',
#  'So there is some sort of justice',
#  'The first two were found unreliable and the prosecution case rested mainly on the evidence of the remaining five approvers .',
#  "They had justified their educational policy of concentrating on the education of a small number of upper and middle-class people with the argument that the new education would gradually ' filter down ' from above .",
#  'And now at present the naturecure, Ayurvedic and modern treatments are taking place through the government in Nepal.',
#  'Parliament time frame is 5 years and this will be dissolved before that.',
#  'ii Register Courts , empowered to try causes for amounts not exceeding Rs 200 , when authorised by the judges .',
#  'Extreme weather due to increased mortality; displacements and economic loss will be compounded through growing population. Although, temperate climate has some benefits out of it such as decreased mortality due to cold weather.',
#  "Of these Lahadi is a popular one .,' ",
#  'Even a concentration of 0.001 ppm of hydrogen sulphide in the water can emit the smell of rotten egg .',
#  "Islam is the world's second-largest religion, after Christianity.",
#  'This changed slowly',
#  'Far more interesting are genetic diseases that arise essentially from the mutation of a single gene allowing a simple Mendelian distribution to appear in the offspring concerned .',
#  'The FIs are expected to offload the stake in favour of Suzuki -LRB- currently 50 per cent stakeholder -RRB- and to the general public later .',
#  'were being produced.',
#  'Naren had three or four meetings with the Consul but found that he was making no progress .',
#  'All those who stand today under this flag are Indians , not Hindus , not Muslims , but Indians .',
#  'In some cases the High Courts have the jurisdiction to deal with matters more effectively as courts of first instance than the Supreme Court .',
#  'And you can see, this LED is going to glow.',
#  'Under the Act more than one Claims Tribunal can be set up and their territorial jurisdiction is specified by notification constituting the Tribunals .',
#  'to turn on the lights or to bring him a glass of water',
#  'Maine',
#  'IN farsi philosophy firdaus garden is presented as ideal one in Mugal literatures.',
#  'Can you imagine saying that',
#  'Head lice need to maintain contact with a host in order to survive .',
#  'Three: this is a good road in - right near where our factory is located.',
#  'This may include injunctions , which can be highly effective preventive measures which can reduce the nuisance caused whilst allowing people to keep their homes .',
#  "What's going on?”",
#  'But after his demise, his bother Sardar Vallabh Bhai Patel did not accept this will and filed a case in the court.',
#  'He also saw with great anguish how , following the ultra-left line of the sixth Comintern congress , the communists had destroyed themselves and gravely damaged the left movement .',
#  'There are also financial reforms in rural China.',
#  'That is the final lesson of the story .',
#  'It is a clash all along , of the old with the new , of real politik with idealism , of the means with-the end , of love claimed as of right and love given of free will , of home-bred virtue with the wild wind from the outside .',
#  'Progressive-minded , he advocated widow remarriage and raising the marriageable age of girls .',
#  'The range was comprehensive , the analysis sober and lucid , and the style so charming that what he said was itself afine specimen of literature .',
#  'Twenty of the years from 1860 to 1908 were years of famine .',
#  'This position is similar to armchair. In this the male puts its legs slightly up near the knees. and his hands are helpful to support the hips of the female. The female spreads her leg touching his back.and after letting her penis inside her vagina takes support on his arms by her hands.In this,he male and female remains quite closer and this provides quite closure.",-',
#  'the family planning started in Vietnam and they went for smaller families.',
#  'category:information technology',
#  'I mean, at that time, trust me',
#  'For Jayendra Saraswati , the spiritual has never been static .',
#  'Not only that',
#  'What we call instinct , what we always refer to disparagingly in our daily lifethis it is that leads us out of the jungle of virtues and vices , elations and afflictions , into an awareness of the unlimited possibilities of our destiny .',
#  'humans destroyed the commons that they depended on.',
#  'Almost goes to E, but otherwise the play would be over.',
#  'Aryans did not make any statues or temples for deities.',
#  'It has three small domes and has been constructed using white marble.',
#  '.Sarojini Naidu with Mahatma Gandhi',
#  'But January 2002 has been quiet .',
#  'External links',
#  "On the rear wall , in a special niche , is carved the usual Somaskanda panel , with Siva and Uma seated with little Skanda on Uma 's lap and Brahma and Vishnu standing behind on either side .",
#  'So I want to share with you a couple key insights',
#  'France , Belgium ; Germany , the United States , Russia , and later , Japan developed powerful industries and began to search for foreign markets for their products .',
#  'But if you agree to allow the seller extra time , you cannot cancel until that time is up .',
#  'Many countries in the [unclear], they need legitimacy.",[',
#  'This change has contributed',
#  'is to create ownership in the community to the problem',
#  'Buddha and danceroom (1958)',
#  "the arrangements for setting short-term goals , regularly reviewing your child 's progress towards those goals , and how your child 's progress is to be monitored .",
#  'He often spoke to us of his own great longing to meet him .',
#  'In this positive connotation , liberty would mean freedom of the individual to do what one likes .',
#  "Thus , even aslthe Central Legislature 's power to make laws for the whole of British India , for British subjects and servants of tie Crown in India , and for all British Indian subjects within as well as without British India was reiterated , it continued to be subject to many important limitations which were designed either to keep the sovereignty of the British Parliament intact or to maintain the supremacy of the Governor-General and his Council .",
#  'greatly understate its impact.',
#  'We use a different style of WP1 application form depending on whether you intend to send the application to us by e-mail or post .',
#  'He wanted to teach gurubhai a lesson and giving respect to all the things of Gurudev ,he took the spitbowl filled with blood and cough and threw it on gurubhai bed.',
#  "1)Sanskrit is world's oldest language of vedas.",
#  'the Carrier Hotel',
#  'that it learns or is pre-programmed.',
#  'Where programmes have been slow to deliver results , for example on truancy , the Government is intensifying action .',
#  'have different colors and different textures to our eye',
#  'parliaments control on financial health.',
#  'However , in the meantime , there was an influx of people from other States particularly from the South and more people were inducted under various other schemes of rehabilitation .',
#  'And I think any wise life will accept',
#  "Among the principal ' infant ' industries of this period mention must be made of sugar , paper , and matches .",
#  'After you have made enough to rebuild the cottage , I shall take you back as my Queen . ”',
#  '2 Sursaravali',
#  'In spite of greater use of machinery on the plantations , the organisation of a colliery was less patterned on the lines of the factory system . IRON AND STEEL INDUSTRY',
#  'While it helps diplomatically to have a country like the UK openly come out with a legislation like this , what is important is the question of the difference this would make to insurgency , say , in Kashmir .',
#  'to create a dry mist',
#  "Chawla's responsibilities included the microgravity experiments, for which the crew conducted nearly 80 experiments studying earth and space science, advanced technology development, and astronaut health and safety",
#  'In the middle of 1700th century,after the beginning of industrial revolution,the atmospheric concentrations of CO2 and CH4 has increased 31% and 149% respectively.During the past 650,000 years ,these levels are considered to be very high than at any time.",CO2 ',
#  'in these the main are farakka dam,tihari dam,and bheemghoda dam',
#  'than are put into malaria.',
#  'when the space race was going on',
#  "Perhaps there are problems that you do n't know about .",
#  'I was forced to get a paper route at 10 years old.',
#  "The religious leaders were fully conscious of such problems and they tried to root out ' discrimination in all its forms .",
#  'At that time the main party to oppose them were the Communist Party of India and other leftist parties alliances to them.',
#  'Class : United States of America',
#  'I then read him a chapter',
#  "If the murdered p jrson is a Brahman , the Brahman murderer has to answer for it in a future life , or he is not allowed to do expiation , because expiation wipes off the sin from the sinner , whilst nothing can wipe off any of the mortal crimes from a Brahman , of which the greatest are : the murder of a Brahman , called vajmbmhmahatya ; further , the killing of a cow , the drinking of wine , whoredom , especially with the wife of one 's own father and teacher .",
#  'Some may want to get every word exactly right while other children will race to the end of a story .',
#  'At that time in rajsabha lord shri Krishna showed his ultimate wide vishwaswaroop and made everyone scare.',
#  'Demand was increasing fast and the mills had to switch over to two-shift working , utilising available idle capacity .',
#  "prior to 14th century,country's maximum area got captured in single state",
#  'In Indian culture, Holy texts have a special importance, and the Purans are among the most important of all the holy texts.',
#  'Fast track courts- These are special courts which have been started with a purpose to quickly proceed with long pending criminal cases or under-trial disputes.',
#  'Abu-Yakub of Sijistan maintains in his book , called The disclosing of that which is veiled , that the species are preserved ; that metempsychosis always proceeds in one and the same species , never crossing its limits and passing into another species .',
#  'permanent, billowing, voluptuous forms',
#  'Other sounds like chirping , rasping , squeaking , whistling and shrieking are deliberately produced by various insects , either as expressions of joy of living or as a means of communication with their friends or warnings to enemies .',
#  'Every five years',
#  'In Burma and Ceylon she intends to hold on as long as she can .',
#  "Vishnusahastranam - Glory of Vishnu's 1000 names in Shantiparva.",
#  'It worked .',
#  'Virtually all groups of plants and animals , and the natural variations that exist within them , are represented in the Life Science Collections .","=',
#  'The number of technically qualified persons employed was inadequate , and the general rank and file of the workers was employed largely on a temporary basis , which was not conducive to greater efficiency .',
#  'The blue and the dim',
#  'Although , the Superintendent of the jail and most of the other local officials were reasonable and avoided giving trouble , the Bengal Government who were ultimately responsible for the prisoners were extremely vindictive and the Government of India entirely indifferent .',
#  'Category : Religion Author',
#  'So we light our buildings with daylight.',
#  'where, the time, the website.',
#  'and that is for their children to grow up successful',
#  '.Masterbation',
#  'Because of these the Supreme Court has made some restrictions on its own',
#  'about the world than the chimpanzees.',
#  'that all three have also been responsible in',
#  'For instance , soft-drink giant Coca-Cola Inc is seeking exemption from a public issue .',
#  'Led by veterans like Sharad Joshi and Bipin Desai , farmers threatened the Government with dire consequences if it went ahead with its plans to destroy their crop .',
#  "It really happens-if you 're good-looking , that is .",
#  'Royal Chitvan National Park',
#  'The hookah smokers will have a lot to talk about .',
#  'As an anniversary it was probably the most important of recent times but it went unnoticed because Phoolan Devi got killed and the prime minister threatened to resign over the interminable UTI drama .',
#  'Sanskrit Liturature:',
#  'Thus by exchanging positions once, he scores one run.',
#  'But we also know where we are through movement.',
#  "Though the possibility of launching a big conspiracy case against the prominent left-wing leaders was being considered from 1927 , the first concrete reference to it is found in Lord Irwin 's secret telegram to the Secretary of State for India on 13th September , 1928 .",
#  "Men of Delhi Police 's Special Cell apprehended Rajesh Bhalla a.k.a . Tutu , 49 , a high-end fashion garments exporter , who had been absconding for nearly six months .",
#  "'Dhamayanthi' or 'Naldhamayanthi' is a love story in 'Aranyakaparva'",
#  'before this ABCL was not succeeded amithab got great problem',
#  '28 . You should send :,28 ',
#  'We were up in the mountains, and Feynman said to me',
#  'class: Agra',
#  'The rules expressly state that the king should try cases with great care and should give decisions according to law , adhering to the opinion of judges .',
#  'People get new clothes stitched.',
#  'The Guru let one bangle slip from his hand into the river below .',
#  'Somewhere between extreme indifference and extreme reaction lies the truth- and the hapless , beleaguered citizen of Bengal .',
#  'We criticized them',
#  '-LRB- More details about going into a Residential or Nursing Home are in the leaflet Choosing Residential And Nursing Home Care -RRB-,"( ',
#  "Many people have a prejudice against goat 's milk due to its peculiar flavour .",
#  "he was one of the constitute members of india's socialist republican association.",
#  'If the report and the thesis of the sixth congress contains the highest wisdom of Leninism , then , as far as the colonial -LRB- particularly Indian -RRB- question is concerned . Lenin , Zinoveiv , Bukharin , Stalin , all in their respective turns , have been anti-Leninist , social democratic lackeys of imperialism . And this is precisely the purport of the resolution on the colonial as well as on other questions of the sixth congress .',
#  '1. This bench will come under political pressure.,1. ',
#  'Because in non technical literature have not clearly definition. so make a difference between the various form of related disease.According to World Heath Organization(WHO) these are define as a asbestosis,Lung cancer,Mesothelioma(It is vary rear cancer),when these are vary general then these are maximum related to asbestos.',
#  'the relics of creation and inferring what happened at the beginning',
#  'Speaker Protem',
#  'Through the mammography we can also diagnose other problems of breast which are not carcinogenic .',
#  'with the same strategy as down here. The improvement of the world',
#  'Paris and Rome and Prague are still there , externally not greatly altered , and yet I wonder how far the spirit and soul of these cities is the same as before .',
#  'Do you remember Hamlet? Act 1, Scene 3:',
#  'The ammonia evaporates',
#  'They take real-time data',
#  'a survey done in mumbai by world gazetteer in 2008, according to that the population of mumbai was 13,662,885',
#  "like you've always got two choices.",
#  'To a very large extent he has to maintain the same role of impartiality and objectivity as that observed by the Speaker .',
#  'granth list',
#  'Can be seen her such property in speech given by her in that occasion.',
#  'The other types are the utsava-mandapas for various periodical festivals where the utsava murtis were decorated , worshipped and taken out in procession .',
#  'Goats are sacrificed and plenty of liquor is drunk , Women paint little vessels -LRB- Auloo -RRB- with clay and decorate it with drawings in red paint .',
#  'See page 56',
#  'was this one, water found on the moon.',
#  'Category : Hindi',
#  'In missionary position lover Yugal; Gustav Limpt 1914',
#  'Been a lone parent for those 26 weeks ',
#  'The advent of new techniques made it possible to bring about mutations in vitro by deliberate design instead of blind chance .',
#  'These artisans were not paid in cash , but received a traditionally fixed share of the produce after harvest .',
#  'Lord Curzon , when consulted , said that there were more distinguished men in India than Tagore .',
#  "The outer surface of the earth is divided into hard sections and plates which are displaced on the surface in many millions of years. Nearly 71% of the surface is covered with salt water and the remaining area is divided into continents and islands, fresh water which is essential for life and whose availability is unknown on other planets. The earth's internal surface has active with a solid layer of mantle, a liquid core which forms a magnetic field and a solid inner iron core.",
#  'In the early twentieth century, the oldest film had started being broadcast here.',
#  'This vast country was Hindustan , Bharat Mata , for all of us who lived in it and were her children .',
#  'Yet the attempts are on and under the various schemes in November 2008 the Indian government declared it as the national river and the path between Allahahbad and Haliya(1600 kilometers)ganga river waterway was declared as the national waterway.',
#  'However , they do not constitute anything like a single all-India cadre .',
#  'the hub of democracy around the world',
#  'In their competition to attract weavers the Bengal mills offered wages which could not be afforded by other weaving industries , which , as a result , were forced out of Bengal .',
#  'But where the defect appears early in life and is so serious as completely to prevent reproduction , as in sickle-cell anaemia , nothing is gained by sterilisation .',
#  'to avoid thinking about being wrong',
#  'Second programme to convert Roman output receieved from Sanskrit_OCR to Devanagari.',
#  'In education , intellect , character and achievement , he can be compared only to the highest among British statesmen , while no Indian could doubt for a moment that the sole aim which drove him into public life was a concern for , and a love of , his native country .',
#  'amazing.',
#  'Blood glucose can drop too low during or after exercise continued for long duration .',
#  'For one and two parent families',
#  'How could girls be sent to schools ; it would mean walking through public places , and contact with men .',
#  'During this, the other players of the bowling team stand at various positions on the field and field the ball. They try to restrict the runs made by the batsman and also try and take his wicket.',
#  'and indeed continue to change those identities',
#  'Regular physical activity can help control your weight , improve your blood circulation and help your heart work more efficiently .',
#  "Other users can't use login in YouTube account from Apple TV Version but can only make the favorite list for i phone",
#  'And, being a little intrigued, I went to go meet this group',
#  "Somebody's storytelling. Interactive art. You can talk to me.",
#  "I'm not saying that it is not reaching at all.",
#  'The 10th day of waxing moon of Ashwin month is celebrated as Vijayadasami.',
#  'actually near Afghanistan',
#  'These persons are appointed by the central government , and hold office for such period as may be specified in the order of appointment , but for not more than five years .',
#  '63. Udaipur was the capital of Mewar, and is currently a District Headquarter.",63. ',
#  'Some videos are for people above 18 years only like adult videos, pornography, nudity, defamation, harassment, advertisements and criminal conduct are prohibited.',
#  'It is meet tosh river in upper area of Himalaya and after reach the Small Himalaya its meet Giri and Aasna River.',
#  'Clinical trials still need to be carried out .',
#  'Video seeing',
#  'And depressing ones, such as the fact that',
#  'the results can be somewhat comical.',
#  'Possibly Tibetan - Bermai had originally arrived in Nepal 2,500 years ago.',
#  'So its rebirth in the form of modern factory manufacturing was to the Indians a revival of the past glory with visions of a great future .',
#  'And finally , there has been much talk but little action about rational energy pricing , reflecting real social cost of alternative sources of energy .',
#  "Beware a dealer who is cagey about a car 's history .",
#  'Stopping people sniffing one thing may turn them to other substances which might be more dangerous .',
#  "a pasting I'd done a year earlier -",
#  'Your strength has sorely been taxed imprisonment , banishment and disease , but rather than impairing , these have helped to broaden your sympathiesenlarging your vision so as to embrace the vast perspectives of history beyond any narrow limits of territory . . .. I feel that you have come with an errand to usher a new light of hope in your motherland . . .',
#  'of these, poverty, unemployment, reducing hygiene and non educated people are the main reasons.',
#  "That's when he falls.",
#  'And I really understood what patient capital meant emotionally',
#  'so Ami Tabar took this and modularized it down to an eighth of an acre.',
#  'Exyernal links',
#  'this student, probably his first time using it, doing very complex manipulation tasks',
#  'And assure them repeatedly that everything will be OK .',
#  'It used to be that Paris and London and New York were the largest cities.',
#  'then men would still be socializing in front of a wood fire',
#  "So it's a very hard model to accept.",
#  'we found them browsing and teaching each other how to browse.',
#  'He hated the sight of excited crowds gloating over bonfires of foreign-made cloth , he pitied the students being made to give up schools and colleges to become pawns in the hands of politicians .',
#  'can be very dangerous.',
#  "A welcome step taken in this direction during the last few years is that the National Book Trust has been arranging short-term Writers ' Camps attended by writers of the various regional languages and publishing under its ' Aadan Pradan ' programme some selected books from each language into all the others .",
#  'These may be designated as Additional Sessions Judges or Assistant Sessions Judges , and they are Judges of the same court .',
#  'The stables should be so constructed as to provide sufficient protection from inclement weather , excessive heat , cold , and rain .',
#  'Therefore, in order to test them Drupad invited them to his court.',
#  "I mean, I've been saying I've been prepping.",
#  'festival (text to speech)-Festival-Hindi chapter to speech program (download)',
#  'You will find in the early days , fifty years ago , a number of very respectable individuals meeting together , a small group of upper class people meeting together , and talking in terms of the crudest loyalty .',
#  'It is a general practice to feed hay before grain is given to the horse .',
#  'Why I am not getting [any]',
#  'I made him “The Uncle Phone.”',
#  "Compilation of Bachan's great poetry .",
#  "There is no central church or religious organization of Hindus and no 'Pope'.",
#  'to fly like a bird.',
#  'Even defence production-the most sacred bastion of swadeshi control-has been opened , though with caveats .',
#  'Muzaffarpur',
#  'Hanuman, son of Ravana by destruction of the Ashokvatika slaughter made of renewable',
#  '2 . When the traffic has stopped , walk across , but keep looking and listening .",2 ',
#  'He blames the Government for the delay in securing infrastructure during the first three months : “ We began hearing only in July . ”',
#  "Krishna Jibon Sanyal is sentenced to one year 's rigorous imprisonment under Section 121-A .",
#  'In the villages , this system is considered most convenient .',
#  "Chawla's last visit to India was during the 1991-1992 new year holiday when she and her husband spent time with her family.",
#  'Many bull operators simply tapped profit-crazy bankers to write out cheques and guarantees . ”',
#  "This is India, and of course it's all the more striking",
#  "The development of photosynthesis in life using the sun's energy directly allowed, resulting in oxygen atmosphere has accumulated and ozone (upper atmosphere, molecular oxygen [o3] A type) was Parient as a part of. As a result of the incorporation of small Koshikaom with large Koshikao Yucaryotess (development of complex cells) say happened in the development of the Jtleie Koshicoma. Under Koloniyom true multi-cellular Jivo is specialized crescent as harmful ultraviolet radiation by ozone layer assisted Awasheshne Perdvi life was calculated on",
#  "Delhi : It 's been two weeks into a fairly raucous monsoon session now but leader of the Opposition Sonia Gandhi has n't made it to the headlines .",
#  'A piece of metal should receive the stamp of the mint and only then it is acceptable as a coin outside .',
#  "This epic sometimes referred to as “”Bharat“” only is India's important religious, historical and philosophical epic.",
#  'Carefully , their is no importance in for getting Canada.',
#  'rule of shariyat and its base is the law study and its called fifah',
#  'when my mom and my dad came to Canada.',
#  'is to help them to stand on their own feet.',
#  'After the 1857 War of Independence , the Andaman and Nicobar Islands served as a convict settlement colony for the British Raj .',
#  'Scenic locations',
#  'These reports , though presumably taken down in shorthand , are scrappy and incomplete , confusing and often making little sense .',
#  'delayed or missed departures ;',
#  'As a result, our complications are significantly lower',
#  'Afterwards they are placed within the house .',
#  'And yet it can be seen that these plants with uniform heredity look very different when grown in different environments .',
#  'Consequently the genes carried in the Y chromosome will have their homologous alleles in the X chromosome so that the XY pairing in the male presents situations different from that of the pairing of autosomes or for that matter , the pairing of the sex chromosomes in the female which carries two of X . If we stretch the Y chromosome along X chromosome as in Fig . 33 , we find that the larger X chromosome may be divided into three segments .',
#  'Externally , the quadrangular open court is surrounded by a prakara with a cloister , or malika , locally called nalambalam or chuttambalam .',
#  'These models are based on, physics principles of liquid movement, radiative transfer and other process. In some places it is simplified, because computer has its limitations, and climate system has vary complexity. All modern climate models has environmental models in it. It get separate from ocean model or soil and models of ice on ocean. Some model have included the treatment of chemical and biological processes. These models measure effect of green house gases and we get worm climate adding these effects. Then also, when using these assumption there is big role of climate sensitivity.',
#  'They are well established forms that have become so thoroughly attuned that they do not and cannot attempt casual visits to their rural relatives .',
#  'The judge and the Advocate General , the military office and the political leaders , all alike , strained their ears and were all attention to hear the memorable statement .',
#  'On the crest of the dome and umbrellas there are famous ingredient of traditional Iranian and Indian architecture that looks good on a Metal urn.',
#  'non-partisan , objective approach ? a parliamentary official has to learn to be in the midst of it all and yet out of it ; and The Secretariats of Parliament are dynamic , develop-big institutions requiring constant attention to keep pace with the growing and changing needs of parliamentarians .',
#  'Sometimes the eyes and nose are covered by a yellowish cheesy discharge .',
#  'Barack Obama is select in year 2009 Nobel Clam Praise for contribution in world clam.',
#  'He started a controversy , describing Arut-pa -LRB- Book of Grace -RRB- as Marut-pa -LRB- Book of Darkness -RRB- , and brought out a tract called Refutation of the Book of False Grace .",? ',
#  'Next room is Deewan-e-khas, which was private conference room of king decorated with a free hand.',
#  'The Ram of Kabeer is not a God who trust the principle of single God.',
#  'This was disastrous enough , but a greater tragedy was soon to befall the industry .',
#  'And they are not going down the right path.',
#  'they ran out of space.',
#  'The acceptance , through an 1803 treaty , of British protection allowed Begum Sumru the security and riches to turn to philanthropy .","1803 ',
#  'Such box cooker also developed, which can be used with cooking food with electricity during the days of rain or fog.',
#  'This war was a part of the hostility since the times of Hazrat Muhammad Sallallahu Alaihi Vasallam.',
#  'the whole Nepal consist on 1471481 kilometers',
#  'in cities around the world.',
#  'Internet in India',
#  'In 1985 their share was 34 per cent , which was still substantial .',
#  'However , he wished by his theory to describe one half of the egg as spread out for the earth , and the other half as placed upon it for cupola , trying to outvie Ptolemy in the planispheric representation of a globe , but without success .',
#  'Tamil',
#  'Premchand is the author of the Hindi literature era|',
#  'Having braved the stench and fought your way up the corridors through armies of petty officials , you finally arrive in the sanctum sanctorum of Mr Bada Sahib .',
#  "and it's getting stronger.",
#  'Nepal ( Wiktionary)',
#  'But when reaction and autocracy and imperialism stand to lose , it does matter , and treaties , however moth-eaten and harmful to the people they might be , have to be preserved .',
#  'Riva',
#  'Illegal or impolitic - some officers( mainly government)',
#  'In1894 she went to England for her higher studies and at that time she studied as well as she has been writing many poems.G',
#  'Initially water supply to this canal was done by making temporary baandh.',
#  'One Mecca Part, and another Madina part.',
#  'To attain Nirvana.',
#  "When Brahma's vision falls on Maya, then we see God in the image of Brahma.",
#  'So, these trajectories here are basically how we would expect people to live',
#  'Most of the highest mountain peaks of the world are situated at Himalaya.',
#  'Nevada',
#  'Thank you.',
#  "But if you're not a native speaker",
#  'we discount sounds that remain the same.',
#  'As a result , production of super varieties was increasing though the acreage was falling .',
#  'The next breakthrough is to cut that 10 million in half again.',
#  'Spread over an area of 8,325 sq km in the Bay of Bengal , these island territories have been known for exotic turtles and virgin tropical forests .',
#  'If we did we could dictate the agenda and Pakistan would have to listen .',
#  'He continued to be a spokesman for the Muslims , and wherever they had valid grievances he knew that any sympathy or help that the Muslims received from others could only be a salve , it could never be a cure .',
#  'one-upmanship.',
#  'if you made literature affordable and available to them.',
#  'No other national leader except Nehru shared that concern .',
#  'Now up until that moment',
#  '',
#  'because all the information, as I said, are inside the DNA.',
#  'if Nike wanted to sell a pair of shoes',
#  'Category: Biography',
#  "Scbaceous prominences: look like spots of mustard emerged from penis's sebaceous glands and common",
#  "you're sitting there, looking at the person, waiting for them to look away",
#  'Clean fresh water should always be provided to them .',
#  'Between Sri Harsha and Vikramaditya there is an interval of 400 years , as I have been told by some of the inhabitants of that region .',
#  'When disturbed or alarmed , this beetle explodes a malodorous and caustic volatile liquid , with a loud report , from its anal end and makes good its escape , leaving behind an utterly confused enemy , overcome by acrid fumes .',
#  'Hindi font checker ad-on for Firefox',
#  'If you temporarily transfer them from an overseas branch or subsidiary or if the person is seconded to you from an overseas employer it may be appropriate for the overseas contract of employment to continue .',
#  '(Laughter),(',
#  'The Government took away a large part of its produce in the form of land revenue and other taxes .',
#  'Apart from his police duties , the Kotwal also enjoyed some judicial powers .',
#  'But they were more anarchists and syndicalists than socialists .',
#  'Drug addiction, you simply want more.',
#  'English Hindi dictionary in PDF form',
#  'They take three to four rounds of a four-kilometre stretch alongside which are placed 15 idols .',
#  'The number of elephants in an akihauhim is 21,870 ; the number of chariots , too , |BAR;s 21,870 ; the number of horses is 153,090 ; the number of men , 459,283 .',
#  "If I spin this pulley, the small one's going to spin much faster.",
#  'is actually when I first returned to Iran',
#  "It can be argued ' that these are spurious rules and to know the real ones we should go to the Vedas or to our philosophy .",
#  "Or perhaps , it was his own disinterest in culture that prevented him from noticing that during the many years of Indira 's leadership , “ immense and priceless ” monuments were allowed to fall to rack and ruin .",
#  'The last incumbent of the British regime before Japanese occupation was Scot .',
#  'Some species might live by freshwater and bite animals , whereas others might live near salt water and bite humans .',
#  'that, believe it or not, I have picked up',
#  'In our mind, the relevant metric',
#  'Many dances are also performed with ancient historical weapons ',
#  'All the ancient medical texts state that prameha of any variety , if neglected , will finally lead to madhumeha and in due course become incurable .',
#  'veda is written in a very difficult and hard language',
#  'This temple built near golf course and airport is believed to be the residence of God.',
#  'And I started watching Kaki King a lot',
#  'The fine Dacca muslin was the envy of the world for centuries together .',
#  'Then as Vyasa guided them to go Panchal state they have gone there and there was the Swayamvara of Droupadi.',
#  "In the secular world we think, “If an idea is important, I'll bump into it.",
#  'You can stay with me for 20 years, go tomorrow.',
#  "At its core is India 's first genetically modified seed , infamously called BT Cotton .",
#  'have had what you might call a spiritual experience',
#  'In the present phase of the Ayodhya movement , the eight worst cities listed above will have to be watched .',
#  'that we developed called IMPASS.',
#  'Ancient Sanskrit literature is extremely old, vast and diverse',
#  "And they go over all this ... I'm going to try to be",
#  'The progress of the major industrial machinery groups is reviewed below .',
#  'Just out of curiosity, how many of you',
#  'The diesel engine has certainly been a boon to modern industry , agriculture and transport .',
#  'This festival celebrates twice in year, but in time period it is limited up to residents of Bihar and Eastern Uttar Pradesh.',
#  'The evolution , according to them , takes place in six stages , where each stage is a reflection of the mental state of the aspirant .',
#  'prostate tumor activity is shown in red - you can',
#  'In 2001, her life changed.',
#  'They have a charming literary quality and they tell us that the author was an ardent devotee of Shiva .',
#  'sort out formal complaints within six months of getting them -LRB- formal complaints are handled under legal rules -RRB- ;',
#  'This inverse relationship suggests another important conclusion .',
#  "this complex is covered with four very big gardens, one is Mogul's garden",
#  'The new state was established in fifth century in vaishali region',
#  'So he takes their radio, talks to their boss',
#  'In the year 1947 after the independence it became the capital of Mumbai state.',
#  "Here in India , I 'm too poor to be twiddling my thumbs , but as I spend my days scrubbing , cleaning , cooking and washing , I also worry and wonder .",
#  'Before his departure for Europe , Subhas Chandra was brought back for a while to Jabalpur jail where his brother was held .',
#  'We can think, really, that each one is sort of',
#  'He further argued that Brahnwnism preached only karma and not bhakti .',
#  'In the meantime, war started between USSR and Japan and they were busy on their borders.',
#  'Scepticism itself , when it proceeds from vigorous natures true to the core , when it is an expression of strength and not of weakness , joins in the march of the Grand Army of the religious Soul . ”',
#  'and we were walking',
#  'He is the only player in the world who scored more than 12000 runs in the test cricket.',
#  'The anti-Congress section of Muslims who had now joined the Muslim League found the cultural issue far more effective in inciting their community against the Congress than the purely religious issue had proved to be .',
#  'Categories of Ministers',
#  'The other areas are Rangat and Great Nicobar .',
#  'Sometimes a blood clot may completely block the flow of blood with severe consequences , i.e . a heart attack .',
#  'many signs are just like the normal signs of growing up .',
#  "Crazy rituals and divine circus , not to speak of the snakecharmer 's roadshow and the naked sadhu 's nirvana rites .",
#  'It was but natural for them to employ in their writings the language of the masses .',
#  'What you see over here, this yellow thing, this is not a death ray. (Laughter)',
#  'Chris Anderson: So, Pranav',
#  'The British policy only helped to transfer resources from peasants and craftsmen to merchants , moneylenders and foreign capitalists .',
#  '“I think so.”,“',
#  "In modern times poet Jagnnatadass ratakar, Kapil Muni in the book by Gangwatraran boon Sea delivers with a thousand Putro Bhagirath the 'Bhagirath - penance “”is a story of being descended from the Ganges to the ground!",
#  'many opinions present regarding reasons of terrorism. they say range demographic socioeconomic for political reasons. demographic factors and crowd can include high growth rate social factors, poverty, unemployment and land term problems may include disenfranchisement, ethnic confict, religious confict, territorial conflict, resources or to use for revenge',
#  '“ IF YOU CAN GIVE CHILDREN EMOTIONAL SECURITY , THEY WILL LEARN BETTER LATER ON - AND YOU WILL HAVE MADE AN IMPORTANT CONTRIBUTION TO THEIR LIVES . ”',
#  'and they said, “No problem. We probably hit some birds.”',
#  'if you want a comic book to do well, make the librarians the hero. It always works well.',
#  'The commencement of Kathak Dance took place between the 6th-7th century in Northern India.',
#  'The address is : http : //www.dss.gov.uk',
#  'The coalition he leads is larger than ever but relatively stable .',
#  'DPC uses naphtha as fuel for its phase I plant .',
#  'This fault can be prevented by changing the cocks at short intervals .',
#  'Shisr Agrwacha linked to the lower side area where the ligament remains Agaratvcha (Fehruanulam) is called',
#  'The philosophy of Khalistan will continue whether I am there or not .',
#  'for the world in general',
#  "we'll wait for you to finish the tea.",
#  "I'm not going to present all the data that I have here today",
#  'a blind person driving using the AirPix.',
#  'stands for life - the word “life.”',
#  'This will depend on the complexity of your complaint .',
#  'He further explains that ” the encouragement in India of religious adventures on the ground of modern liberalism tends to make people more and more indifferent to religion and will eventually completely eliminate the important factor of religion from the life of the Indian community .',
#  'The company made an offer to buy shares of its Indian subsidiary from shareholders , which will eventually lead to its delisting from stock exchanges .',
#  'than HIV/AIDS',
#  'But male chauvinism was its blind side .',
#  'There is no chance of the Hindu and Muslim religion one and the same.',
#  'In many cases the structure of Government meant that the joined-up problems of social exclusion did not receive a joined-up response . In particular :',
#  'The Forest Department has also a sale depot at this place where the visitors can get souvenirs made of rare species of timber .',
#  'shot at the same height and in the same type of light.',
#  'RELIGIOUS CONDITION The major religions practised in KarnataKa during the first half of the twelfth century were : Jainisru , Yaishnavism , Shaivism and Buddhism .',
#  'have begun to walk parts of the path of Abraham',
#  'In 33 year of creative life he give the literature legacy,which is a invaluable as a quality point of view and point of shape it is infinity.',
#  'Is this job tough? You betcha. Oh God, you betcha.',
#  'He took care of him.',
#  'But later, the British became too heavy to handle and both the armies had to withdraw.',
#  'In particular , employment prospects became increasingly bleak for those who were forced to drop out from the universities without getting a B.A . degree .',
#  'For full feeling wish one has to glad one or many devtas by worship and pray.',
#  'True , there is an inherent subsidy to any plain postal system but bottom lines can he helped by an innovative mix of franchising and value addition .',
#  'With Mahadevi, Hazari Prasad Dwiwedi and others.',
#  'For he foretold of a period',
#  'Sree Ramchrita Manas- Lenka Kaant',
#  'Slowly this disaffection extincted.',
#  'This was the first step towards the creation of Rajasthan.',
#  'The Eastern Chalukyas of Vengi , a collateral branch of the early Chalukyas of Badami , however , have left a series of structural temples in sandstone which are more akin in their style to the Pallava style of Tondaimandalam to their south .',
#  'These animals are heavy milk-yielders .',
#  'Sharif found it expedient to welcome Vajpayee as he was then trying to seek a dialogue with India because of economic compulsions and the international pressure after the 1998 nuclear tests .',
#  'To think (to follow behind) on Quran after reading, this is the true rights of Tilawat.',
#  'It happened by worldwide voting where it got 10 crore votes.',
#  'but we should also remember',
#  "Air pollution's sources can be various places, activities and incidents which are",
#  "After reaching to Madina from Makka, Mohammad Sahib has made a treaty with the Jews of there, in which religious and cultural autonomy of Jew's accepted.",
#  'Once that trust was built',
#  'that lie inside us',
#  'With at least one crude-oil tanker passing through these straits every 30 minutes , the hike in the freight charges will be enormous in the worst-case scenario .',
#  'Sangini(Saturday)',
#  'Federal areas also get representation in Rajya Sabha for that have only federal appearance',
#  "And of course, most of you don't support the insurgency;",
#  'Once someone in the service of Gurudev(teacher),showed hatred and carelessness and out of his hate redness compressed his nose and eyebrows.',
#  'Prices continued to rule high , affording no relief to the consumer even during periods of glut .',
#  "It's your resource, it's not somebody else's.",
#  'You may have noticed it',
#  'Such a strategy has worked well in the past in Orissa , a state that suffers from a lack of industrialisation .',
#  'Daily Yashaarat',
#  'such as, “I really want to run this marathon',
#  'the values that you espouse.',
#  'Most of higher secondary schools in city affiliated with “”Mumbai Vishwa Vidhyalaya“”, which is one of the most students containing schools in the world.',
#  'not just us primates',
#  'in this book the condition of those who died is there',
#  'The prastara over this outer wall of the vimana and its forward mandapa wall extension carries a hara of karnakutas and salas corresponding to the relieved bays below .',
#  'And that animated graphics can make a difference.',
#  '” In my view the Congress is nothing more . . . than an assembly of educated people from all parts of India and representing all races and creeds , met together for the discussion of only such questions as may be generally admitted to concern the whole of India at large . . .',
#  'From here it came to Pakur through Mirzapur,Patna,and Bhangalpur.',
#  'A more serious consequence of noise pollution is the chronic damage to the hair cells in the-inner ear .',
#  'that fundamentally expanded my perception',
#  'People say that he is not allowed to stay in a country in which the grass which he wears on the ring-finger does not grow , nor the black-haired gazelles graze .',
#  "And we've got to absolutely work with these kind of minds",
#  'This was to secure its writ outside Kabul and in the Pashtoon-dominated areas .',
#  'The Third Plan set the target at 10.2 million tonnes of steel ingots , almost all the additional capacity being earmarked for the public sector .',
#  'and my mother finally says to me, “I knew it, I knew it.',
#  'It is more economic and efficient than the steam engine , which it fast displaced .',
#  'Pakistan has enormous geographical variations, ranging from sea coasts (beaches)in south to ice-capped peaks of the Himalayan (Karakoram) and Hindukush ranges in the north.',
#  'To reach this level and to continue emission after 2100, the natural oils is present if coal tar sands or methane clathrate are being used',
#  'These messages were started from Aadam.',
#  'A little neglect may cause loss of a valuable animal .',
#  'In Madras the Company also tried to attract the workers to seek employment in workshops as in the days of the old courts .',
#  'Acts that could be said to have adversely affected the well-being of the community were considered affronts to the gods , and calamities and disasters such as the plague , earthquakes , etc . were seen as expressions of divine anger .',
#  'He renewed old acquaintances and made new ones , among them the two remarkable ladies , Helen Keller and Jane Addams .',
#  'Rajasthan in ancient days',
#  'was demonstrated by studies of interference',
#  'It brought us hope.',
#  'The last group was being guided by A.C.N . Nambiar , who had organised an Indian Information Bureau on behalf of the Indian National Congress in Berlin .',
#  'He tackled a ministerial crisis in the Central Provinces skilfully .',
#  "The reason of popularity of 'Dainik Jagran' is its dedication towards the public.",
#  'From Taila to Vikramaditya it progressed steadily : the boundaries of the empire were extended , many beautiful temples were built and men of letters were honoured .',
#  'The Government is still to figure out how many of those living in the old , walled cities would shift outside .',
#  "Pranitha's mother was a woman in prostitution",
#  'His Holiness the Karmapa: Tomorrow is my Talk.',
#  'But it does require a lot of planning.',
#  "She poisoned the king 's ears against them , and finally got them banished into the forest .",
#  'Fibbi is a part of Ashtank software for its Hindi awareness campaign.',
#  'as many speakers have said during the past few days',
#  'Imports stopped and the demand increased .',
# ...
#  'hence why Remi is so different from Sam.',
#  'I have a corresponding milestone to robust human rejuvenation.',
#  "Bharali , a classical singer , said Mahanta 's security officers , including a superintendent of police , and the then minister for rural development Sahidul Alam Choudhury attended the ceremony between 11 p.m . and 1 a.m . on March 11 , 2001 .",
#  'First , he needs to give the country a healing touch of reconciliation by reaching out to the political forces .',
#  'made for two dollars.',
#  "I wouldn't be doing my job -",
#  'The pillars are huge in size with kumbhas or cushion capitals , and the statutory inside is also ponderous and of large proportions .',
#  "Ambedkar said in the Constituent Assembly that by parliamentary democracy we mean ' one man , one vote ' .",
#  'India is going to have',
#  'Plaque that builds up along the gumline and between teeth in hard to reach places can be harmful .',
#  'and he was practicing his French.',
#  'This is a project called Photosynth',
#  'The general index of industrial production with 1970 as base rose to 149.7 in 1979 .',
#  'It was estimated that in 1951 , there were some 25,980 mill looms and 181,278 handlooms engaged in the manufacture of art silk fibres .',
#  'Radioactive pollutants ,nuclear explosions and war explosives which comes from radio darmik pollution.',
#  'The great upheavel changed the direction of the flow of the waters to the south .',
#  'Do this at least three weeks before you intend to stop .',
#  'And the facts he presented even with the witnesses were not accepted by the supreme court.',
#  'So for any problem, the more you can zoom out and embrace complexity',
#  "If the enthusiasm of the ministers to air their views in public for publicity is predictable , Jaitly 's emotional and spirited intervention in this matter is vexing to say the least .",
#  'And he said, “If my wish gets fulfilled” -',
#  'Solar energy: Sun is renewable & environment friendly source of great energy.Therefore, people have found it to be the way of life & culture.',
#  'Gandhiji is told that the failure of Pattabee Sitarmaiyya is his own failure,and told the his partner if they are not agree with Subhashbabu style,so they are move the congress.',
#  "If there is more than one arbitrator , the parties have to appoint an ' umpire ' to whom the dispute is referred if there is any disagreement between the arbitrators .",
#  'The sandhara and sarvatobhadra forms are the most outstanding .',
#  'I believe we have to attend',
#  'All the major religions give us calendars.',
#  'Now I am having a title like',
#  'Mahanta survived an assassination bid by the ULFA but not the stigma of the Rs 200-crore veterinary scam .',
#  'after some days, subash babu was acquitted out of congress.',
#  'And then finally',
#  'and the Lebanese',
#  'This word is made in Pharisee word Paridaeza this mean is one wall protected garden.',
#  "Most of Roy 's loyal supporters as well many left-wing nationalists , who had come to his defence , were in jail .",
#  'The rest is for others .',
#  'A Ghana Airways pilot falls into the same predicament.',
#  'In some instances the person who ventured to bring a breach to a court , himself got into trouble for his pains and was fined .',
#  'The Quran has dealt with the attributes of God definitely and comprehensively but it observes the greatest caution in discussing His Essential Being .',
#  'features:full options,online,devanagiri supported(WYSWYG)',
#  'Brahma has two forms: Parabrahma and Aparbrahma',
#  'The next day in the Jammu sector , they killed 19 people , including 15 Hindu residents , women and children in Doda .',
#  'Having done his work and won his fight in South Africa , Gandhi had returned to his country but had not yet made up his mind what he was going to do or where he was going to stay .',
#  'These are the three main tiers in our Criminal Courts .',
#  "The temple became everything ' to him .",
#  'Myth : Flooding of imported goods is hurting the Indian industry .',
#  'to certainty.',
#  'There are a bit harder issues.',
#  'But Dr Tarachand in his valuable book The Influence of Islam on Indian Culture has proved that these movements were inspired by the impact of Islam .',
#  'trust me, we will sink to them.',
#  'They see us as adults, rational adults.',
#  "Late Shri G.V . Mavalankar , the First Speaker of Indian Parliament , held that the Committee on Subordinate Legislation is the ' custodian of the duties of Parliament ' and keeps the administration within bounds intended by Parliament .",
#  'Thus , in the final analysis , there are only two forces in India todayBritish imperialism and the Congress representing Indian nationalism .',
#  'A lot more to be said about that.',
#  "India has taken note of US President George W . Bush 's State of the Union address where he labelled the Pakistan-based JeM as part of the “ terror underworld ” and praised Musharraf 's “ strong leadership ” .",
#  'Dainik Jagaran (e-paper,Unicoded)',
#  "So what we're saying is that scalability",
#  "To be sure , the scale of the state Government 's rebuilding project was staggering .",
#  'However , every time the period of reservation comes to an end , the Government in its wisdom decides to extend it further by amending the relevant provision of the Constitution -LRB- article 334 -RRB- .',
#  'A batsman can be out by 10 ways and some are not common and very less examples are found of it. Out can be made by bold, catch, lbw, run out, stumped and hit wicket.Common one is to hit a ball two times, handling the ball, time out and destroying the ground.',
#  'They can come in to you account or a sub account or whatever.',
#  'She uses the main gallery as a shelter for larvae that hatch .',
#  'The court of the emperor was the highest court of appeal , the supreme tribunal of the land .',
#  'Their demand was the Government should “ remove all obstacles ” to the building of a Ram temple at the former site of the Babri Masjid by March 12 .',
#  'This era has shown immense devotion among the people of that time.',
#  'For people bringing up a child or children',
#  'Temperature of the lower troposphere has increased by 0.12 to 0.22 degrees C (0.22 to 0.4 degrees F) every decade, as per the satellite temperature measurements. It is generally agreed that before 1850, for the last one or two thousand years, temperature has almost remained constant, with some occassional ups and downs, like the Medieval Warm Period and the Little Ice Age.',
#  'sitting at a keyboard.',
#  'These circumstances show that the persons on board in charge of Savarkar might well have believed that they could count on the assistance of the French police .',
#  "It does n't have to be anything special ; it could be a trip to the cinema , a visit to a football match , or even just watching television together .",
#  'Also contact your Jobcentre for more information about schemes to help you start work .',
#  'On this pretext, the British Government arrested Subhashbabu & kept him imprisoned at Mandaley jail in Myanmar without suing him.',
#  'And she wakes up, and she looks down at herself',
#  'The Committee performs a vital role in safeguarding the powers and prestige of the Parliament and its members .',
#  'Because doodling is so universally accessible',
#  'after the touch of lord shiva to ganga .ganga became a sacred river and the people of universe started worshipping it',
#  'Bharat Operating System Solution or BOSS',
#  'Those dreams are for India , but they are also for the world , for all the nations and peoples are tot -RRB- closely knit together today for any one of them to imagine that it can live apart .',
#  'London, United Kingdom',
#  'On 12th October, 2007, Bachan left his claim on land in Daulatpur village in Barabaki District, Uttar Pradesh.',
#  'Wear bright colours/fluorescent clothing during the day and reflective clothing at night as a pedestrian , cyclist or motorcyclist .',
#  'Elephanta caves are declared as world heritage.',
#  'using what my students call the granny cloud.',
#  'Sidharth started searching for the answers of his questions along with two Brahmins.',
#  'Really Simple Syndication is abnormal',
#  'He decided to kill police superintentant Sinders secretly.',
#  'Akbar was born in the palace of Rana Amar Sal in Umar Kot, Sindh [in present Pakistan] on 23 November, 1542 [According to Hijri, 4th Day of Rajjab, 949].',
#  'The draft declaration , which calls for reparation for slavery , has upset nations including the US .',
#  'The principal functions discharged by such tribunals were conciliatory and local rulers did not usually interfere in their working .',
#  'about my connection with Feynman',
#  'if in the match every team is to play one innings then the no of balls is fixed. so the limited over match is called the one day match.so the team which makes maximum runs win the match.here draw does not take place.if due to monsoon and rains play is interrupted then only match is called as draw also there is duck worth Lewis system there which winner is announced.',
#  'propane and benzene',
#  'In that case the king has no right to meddle with the inheritance , but it is exclusively spent on alms-giving .',
#  'But rivals say he is vainglorious and never misses an opportunity to promote himself , something quite un-RSS like .',
#  "India has acquired the confidence to assert its legitimate Asian role , and it 's ready to reach out .",
#  'daal bati',
#  'But literally within days of arriving I was told, in no uncertain terms',
#  'I , therefore , request all , Hindus and Muslims , to unite and increase your strength as early as possible .',
#  "because that's what brings joy to life.",
#  'To this he answered yes old light will go and new will arrive',
#  'every day, in an act closely associated with',
#  'By Article 141 of the Constitution of India the framers of the Constitution have provided that “ the law declared by the Supreme Court shall be binding on all courts within the territory of India ” .',
#  'The city became like a second paradise.',
#  'and my homeland.',
#  'In addition to this general objective , the railway expansion programme has been oriented to meet specific developmental problems encountered from time to time .',
#  'is very, very different, and the countries are moving more or less',
#  'This will show the magistrates that you have an arguable case .',
#  'They are raised primarily for meat .',
#  'He was a writer of immense talent.',
#  'When he recovered it , ” I was as if no longer the same man .',
#  'Bachhan take an effort to return as an actor through Mrityudaata made by A.B.C.L in 1997',
#  'The immortal door of Fateh pur Sikri.',
#  'Free exports were banned to relieve pressure on the transport system , and an export duty was imposed in 1916 and enhanced in 1917 , but exports of jute manufactures increased all the same , underlining the monopoly India enjoyed in this respect .',
#  'Visiting hours: 6.00 AM to 7.30 PM (friday closed)',
#  'Hajrat Harif is telling that when he entered in Masjid he watch some people quarrel on the problem.',
#  'a couple back-to-school licenses in Spain and Turkey.',
#  'Players make Rs 50,000-60,000 per tournament .',
#  'Thus , the boy grew more thoughtful and introspective .',
#  'It is difficult to translate in English',
#  'NEW WINDS AND NEW CURRENTS Islam in the South , Advaita , Bhakti and Rajput Culture -LRB- AD 700AD 1000 -RRB- THE 300 years after Harsha were a period of political disintegration and intellectual stagnation .","7 . ',
#  'They are to be found in the hills of Vijayawada and Mogulrajapuram on the north bank , all in Krishna district , and in the hills of Undavalli , Penamaga , and Sitaramapuram on the south bank in Guntur district .',
#  'history a very important task',
#  'We saw earlier that Bijjala became an emperor by unfair means .',
#  'Bothered by Noise -LRB- 96 EP 181 -RRB-',
#  'He groomed us, the three of us',
#  'this in 1998 was built by page and Brain surgeon',
#  '1. The proceedings and verdicts of the court can be presented as evidence in the other courts.,1. ',
#  'than we ever would have thought.',
#  'Bollywood, Hindi Film Industry is also situated in Mumbai.',
#  'The first one was miniaturization.',
#  "State of Rajasthan and In GolakNath 's case , the Supreme Court by a 6 : 5 majority reversed its earlier decisions and held that the fundamental rights enshrined in the Constitution were transcendental and immutable , that Art . 368 of the Constitution laid down only the procedure for amendment and did not give to Parliament any substantive power to amend the Constitution or any constituent power distinct or separate from its ordinary legislative power , that a Constitution Amendment Act was also law within the meaning of Art . 13 and as such Parliament could not take away or abridge the fundamental rights even through a Constitution Amendment Act passed under Art . 368 .",
#  'with multinational budgets',
#  'The Bureau of Industrial Costs & Prices -LRB- BICP -RRB- recommended in 1977 a minimum return on capital .',
#  'He had to put up with it . The whole ceremony seemed meaningless to him . He wore the sacred thread and was taken to a teacher for education .',
#  'Lipikaar: The most famous order to type in Hindi. Lipikaar software have won many awards. Use elaborately.,Lipikaar: ',
#  'The change in tension so achieved alters the pitch of the parchments and very attractive tonal effects can thus be produced .',
#  'Both are waterfront communities that host both industries',
#  '(Applause),(',
#  "So, it's a bit of a curve, that.",
#  'It is not just the amount of sugar that matters , but how often sugary things are taken .',
#  'There is first the excitement of entering a government building that reeks of uncleaned toilets and unopened files .',
#  'The kapota tiers are decorated by relieved kuda , motifs , particularly at the centre on each side .',
#  'New World',
#  'Shree Purushottam Nagesh had many times tried to proove the superiority of Hindu religion over others.',
#  'a batsmen can leave the field without getting out.if he gets an injury then he can leave as retired hirt.he will be replaced by the next batsmen.he is registered as retired hurt or retired ill. retired batsmen is a not out and he can come again later.',
#  'before that, in the year 1930, poet Muhammad Iqbal had suggested two different countries.',
#  'Know what is normal for you',
#  'HEC is now undertaking a programme of product diversification .',
#  'The first of these objectives demands that all boys and girls , without distinction of class or caste should be educated under a system of free and compulsory primary education and all talented children should have an equal opportunity for higher education .',
#  'but which you can get around',
#  'The Government announced in the 2002 Budget that 5 million per annum would be made available to fund transport solutions for jobseekers in the 63 areas covered by Action Teams for Jobs .',
#  'Veerappan has released his famous hostage and melted back into the jungles whence he came , and since public memory is short we will quickly forget the ugliness of the Indian state that this shameful episode brought so painfully into focus .',
#  'the energy which is taken from it used in many ways',
#  'After the huge success of Sholey Bacchan had established himself as strong actor and from 1979to1985 he bagged many filmfare awards and a lot of glory',
#  'He said I was throwing my life away',
#  '(Laughter),(',
#  'who were the original hackers.',
#  'They considered it absurd to wait for the unravelling of these mechanisms and give up attempts to alter heredity of plants and animals by more empirical down-to-earch approaches to its control by environmental factors .',
#  '30. The economy of the city was dependent on hand crafts, clothes, metal utensils and some other industries.",30. ',
#  'up to 80 percent.',
#  'is how you actually define poverty. What does it mean',
#  'There may be slight inconvenience in some women .',
#  'He also knows that he works for a government that has brought the economic reform process to a grinding halt but he still talks of miracles and a 7 per cent growth .',
#  ...]

# %%
hindi_sentences = [hindi_sentences[idx] for idx in valid_sentence_indices]
english_sentences = [english_sentences[idx] for idx in valid_sentence_indices]

# %%
from transformer import Transformer
import torch

D_MODEL = 512
BATCH_SIZE = 30
FFN_HIDDEN = 2048
NUM_HEADS = 8
DROP_PROB = 0.1
NUM_LAYERS = 1
MAX_SEQUENCE_LENGTH = 300
HINDI_VOCAB_SIZE = len(hindi_vocab)

transformer = Transformer(d_model=D_MODEL, 
                          ffn_hidden= FFN_HIDDEN,
                          num_heads=NUM_HEADS, 
                          drop_prob=DROP_PROB, 
                          num_layers=NUM_LAYERS, 
                          max_sequence_length=MAX_SEQUENCE_LENGTH,
                          kn_vocab_size=HINDI_VOCAB_SIZE,
                          english_to_index=english_to_index,
                          kannada_to_index=hindi_to_index,
                          START_TOKEN=START_TOKEN, 
                          END_TOKEN=END_TOKEN, 
                          PADDING_TOKEN=PADDING_TOKEN)

# %%
transformer
# Out:
# Transformer(
#   (encoder): Encoder(
#     (sentence_embedding): SentenceEmbedding(
#       (embedding): Embedding(82, 512)
#       (position_encoder): PositionalEncoding()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): SequentialEncoder(
#       (0): EncoderLayer(
#         (attention): MultiHeadAttention(
#           (qkv_layer): Linear(in_features=512, out_features=1536, bias=True)
#           (linear_layer): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (norm1): LayerNormalization()
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (ffn): PositionwiseFeedForward(
#           (linear1): Linear(in_features=512, out_features=2048, bias=True)
#           (linear2): Linear(in_features=2048, out_features=512, bias=True)
#           (relu): ReLU()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (norm2): LayerNormalization()
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (decoder): Decoder(
#     (sentence_embedding): SentenceEmbedding(
#       (embedding): Embedding(135, 512)
#       (position_encoder): PositionalEncoding()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layers): SequentialDecoder(
#       (0): DecoderLayer(
#         (self_attention): MultiHeadAttention(
#           (qkv_layer): Linear(in_features=512, out_features=1536, bias=True)
#           (linear_layer): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (layer_norm1): LayerNormalization()
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (encoder_decoder_attention): MultiHeadCrossAttention(
#           (kv_layer): Linear(in_features=512, out_features=1024, bias=True)
#           (q_layer): Linear(in_features=512, out_features=512, bias=True)
#           (linear_layer): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (layer_norm2): LayerNormalization()
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (ffn): PositionwiseFeedForward(
#           (linear1): Linear(in_features=512, out_features=2048, bias=True)
#           (linear2): Linear(in_features=2048, out_features=512, bias=True)
#           (relu): ReLU()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm3): LayerNormalization()
#         (dropout3): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (linear): Linear(in_features=512, out_features=135, bias=True)
# )

# %%
from torch.utils.data import Dataset, DataLoader

class TextDataset(Dataset):
    def __init__(self, english_sentences, hindi_sentences):
        self.english_sentences = english_sentences 
        self.hindi_sentences = hindi_sentences

    def __len__(self):
        return len(self.english_sentences)
    
    def __getitem__(self, idx):
        return self.english_sentences[idx], self.hindi_sentences[idx]

# %%
dataset = TextDataset(english_sentences, hindi_sentences)
len(dataset), dataset[1]
# Out:
# (90289,
#  ("I'd like to tell you about one such child",
#   'मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहूंगी'))

# %%
train_loader = DataLoader(dataset, BATCH_SIZE)
iterator = iter(train_loader)
for batch_num, batch in enumerate(iterator):
    print(batch)
    if batch_num > 1:
        break
# Out:
# [('politicians do not have permission to do what needs to be done.', "I'd like to tell you about one such child", 'This percentage is even greater than the percentage in India.', "what we really mean is that they're bad at not paying attention.", '.The ending portion of these Vedas is called Upanishad.', 'The then Governor of Kashmir resisted transfer , but was finally reduced to subjection with the aid of British .', 'In this lies the circumstances of people before you.', 'And who are we to say, even, that they are wrong', "You may want your child to go to a school that is not run by the LEA - a non-maintained special school or an independent school that can meet your child 's needs .", 'Please ensure that you use the appropriate form .', 'This period summarily is pepped up with devotion.', 'So there is some sort of justice', 'The first two were found unreliable and the prosecution case rested mainly on the evidence of the remaining five approvers .', 'And now at present the naturecure, Ayurvedic and modern treatments are taking place through the government in Nepal.', "Of these Lahadi is a popular one .,' ", 'This changed slowly', 'Far more interesting are genetic diseases that arise essentially from the mutation of a single gene allowing a simple Mendelian distribution to appear in the offspring concerned .', 'were being produced.', 'Naren had three or four meetings with the Consul but found that he was making no progress .', 'All those who stand today under this flag are Indians , not Hindus , not Muslims , but Indians .', 'In some cases the High Courts have the jurisdiction to deal with matters more effectively as courts of first instance than the Supreme Court .', 'And you can see, this LED is going to glow.', 'Under the Act more than one Claims Tribunal can be set up and their territorial jurisdiction is specified by notification constituting the Tribunals .', 'to turn on the lights or to bring him a glass of water', 'Maine', 'IN farsi philosophy firdaus garden is presented as ideal one in Mugal literatures.', 'Can you imagine saying that', 'Head lice need to maintain contact with a host in order to survive .', 'But after his demise, his bother Sardar Vallabh Bhai Patel did not accept this will and filed a case in the court.', 'He also saw with great anguish how , following the ultra-left line of the sixth Comintern congress , the communists had destroyed themselves and gravely damaged the left movement .'), ('राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह करने कि अनुमति नहीं है ', 'मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहूंगी', 'यह प्रतिशत भारत में हिन्दुओं प्रतिशत से अधिक है।', 'हम ये नहीं कहना चाहते कि वो ध्यान नहीं दे पाते', 'इन्हीं वेदों का अंतिम भाग उपनिषद कहलाता है।', 'कश्मीर के तत्कालीन गवर्नर ने इस हस्तांतरण का विरोध किया था , लेकिन अंग्रेजों की सहायता से उनकी आवाज दबा दी गयी ', 'इसमें तुमसे पूर्व गुज़रे हुए लोगों के हालात हैं।', 'और हम होते कौन हैं यह कहने भी वाले कि वे गलत हैं', 'हो सकता है कि आप चाहते हों कि आप का नऋर्नमेनटेन्ड ह्यबिना किसी समर्थन के हृ विशेष स्कूल , या किसी स्वतंत्र स्कूल में जाए , इजसके पास विशेष शैक्षणिक जऋऋरतों वाले बच्चों के प्रति सहूलियत हों . ', 'कृपया यह सुनिश्चित कर लें कि आप सही फॉर्म का प्रयोग कर रहें हैं ', 'यह काल समग्रतः भक्ति भावना से ओतप्रोत काल है।', 'तो वहाँ न्याय है', 'पहले दो को अविश्वसनीय मानकर बाकी पांच मुखबिरों के आधार पर मुकदमा चलाया गया ', 'हाल में नेपाल के हस्पताल सामन्यतया आयुर्वेद, प्राकृतिक चिकित्सा तथा आधुनिक चिकीत्सा करके सरकारी सेवा विद्यमान हे ।', 'लाडड़ी लोकप्रिय स्त्री नृत्य है ', 'धीरे धीरे ये सब बदला', 'एक ही जीन के उत्परिवर्तन के कारण होने वाले आनुवंशिक रोग इन सभी रोगों से अधिक महत्वपूर्ण हैं.मेंडेल के सरल वितरण के नियम के अनुसार यह जीन संतानों में प्रकट होता है ', 'उत्पन्न नहीं कि जाती थी', 'नरेंद्र ने कौंसिल से तीन या चार मुलाकातें की किंतु उन्होनें महसूस किया कि वे किसी भी प्रकार से बात आगे नही बढ़ा पा रहे है ', 'जो भी इस झंडे के नीचे खड़ा है वह न हिंदू है , न मुसलमान , बल्कि वह हिंदुस्तानी है ', 'कुछ मामलों में प्रथम स्तर के न्यायालय होने के कारण उ ...
# [('There are also financial reforms in rural China.', 'That is the final lesson of the story .', 'It is a clash all along , of the old with the new , of real politik with idealism , of the means with-the end , of love claimed as of right and love given of free will , of home-bred virtue with the wild wind from the outside .', 'Progressive-minded , he advocated widow remarriage and raising the marriageable age of girls .', 'The range was comprehensive , the analysis sober and lucid , and the style so charming that what he said was itself afine specimen of literature .', 'the family planning started in Vietnam and they went for smaller families.', 'I mean, at that time, trust me', 'For Jayendra Saraswati , the spiritual has never been static .', 'Not only that', 'What we call instinct , what we always refer to disparagingly in our daily lifethis it is that leads us out of the jungle of virtues and vices , elations and afflictions , into an awareness of the unlimited possibilities of our destiny .', 'humans destroyed the commons that they depended on.', 'Almost goes to E, but otherwise the play would be over.', 'Aryans did not make any statues or temples for deities.', 'It has three small domes and has been constructed using white marble.', '.Sarojini Naidu with Mahatma Gandhi', 'External links', "On the rear wall , in a special niche , is carved the usual Somaskanda panel , with Siva and Uma seated with little Skanda on Uma 's lap and Brahma and Vishnu standing behind on either side .", 'So I want to share with you a couple key insights', 'France , Belgium ; Germany , the United States , Russia , and later , Japan developed powerful industries and began to search for foreign markets for their products .', 'But if you agree to allow the seller extra time , you cannot cancel until that time is up .', 'This change has contributed', 'is to create ownership in the community to the problem', "the arrangements for setting short-term goals , regularly reviewing your child 's progress towards those goals , and how your child 's progress is to be monitored .", 'He often spoke to us of his own great longing to meet him .', 'In this positive connotation , liberty would mean freedom of the individual to do what one likes .', 'greatly understate its impact.', 'He wanted to teach gurubhai a lesson and giving respect to all the things of Gurudev ,he took the spitbowl filled with blood and cough and threw it on gurubhai bed.', 'the Carrier Hotel', 'have different colors and different textures to our eye', 'parliaments control on financial health.'), ('ग्रामीण चीन में आर्थिक नवीनीकरण हुये हैं।', 'यह इस कहानी का अंतिम सबक है ', 'इसमें टकरवा ही टकराव है - नए के साथ पुराने का , राज्य सत्ता बनाम आदर्शवाद का , साध्य और साधन का , अधिकार पूर्ण प्रेम और प्रेम की स्वतंत्रता का , और बाहरी जंगली हवा के साथ ग्राहस्थिक या घरेलू मूल्यों का ', 'अपने प्रगतिशील विचारों के कारण उन्होंने विधवा-विवाह और कन्याओं की विवाह योग्य आयु-सीमा बढ़ाने की भी वकालत की ', 'विश्लेषण और विवेचन बड़े गंभीर और सरस थे और शैली इतनी मोहक थी कि सारा-का-सारा लेखन साहित्य का उत्कृष्ट निदर्शन बन गया ', 'वियतनाम में परिवार योजना शुरू हो गई और उनके परिवार छोटे होने लगे।', 'मेरा मतलब, उस समय, सही मानिए', 'जयेंद्र सरस्वती के लिए अध्यात्म कभी कोई स्थिर चीज नहीं रही है ', 'बस वही नहीं', 'जिसे हम प्रवृत्ति कहते हैं और जिसे हम अपने दैनंदिन जीवन में बहुत तुच्छ समझ कर नकार दिया करते हैं- यही वह चीज है जो हमें सदगुणों या दुर्गुणों के अरण्य से बाहर निकालने में सहायक बनकर हमारी नियति की असीम संभावनाओं तक और हमारी चेतना एवं उल्लास तथा अनुताप तक ले जाती है ', 'मानवों ने उन ही साझे संसाधनों को नष्ट किया जिन पर वो आधारित थे।', 'रचना करीब करीब ई तक जाती है, मगर तब तो नाटक ख़त्म हो जाएगा', 'आर्य देवताओं की कोई मूर्ति या मन्दिर नहीं बनाते थे।', 'यह एक छोटी तीन गुम्बद वाली तराशे हुए श्वेत संगमर्मर से निर्मित है।', 'महात्मा गांधी के साथ सरोजिनी नायडू', 'बाहरी कड़ियाँ', 'पिछली दीवार पर एक विशेष ताक में , एक सामान्य सोमस्कंद फल्क उकेरा गया है , जिसमें शिव और उमा बैठे हुए हैं , नन्हाँ स्कंद उमा की गोद में हैं और दो ...
# [('However , in the meantime , there was an influx of people from other States particularly from the South and more people were inducted under various other schemes of rehabilitation .', 'And I think any wise life will accept', "Among the principal ' infant ' industries of this period mention must be made of sugar , paper , and matches .", '2 Sursaravali', 'In spite of greater use of machinery on the plantations , the organisation of a colliery was less patterned on the lines of the factory system . IRON AND STEEL INDUSTRY', 'While it helps diplomatically to have a country like the UK openly come out with a legislation like this , what is important is the question of the difference this would make to insurgency , say , in Kashmir .', 'to create a dry mist', 'in these the main are farakka dam,tihari dam,and bheemghoda dam', 'than are put into malaria.', 'when the space race was going on', "Perhaps there are problems that you do n't know about .", 'I was forced to get a paper route at 10 years old.', "The religious leaders were fully conscious of such problems and they tried to root out ' discrimination in all its forms .", 'At that time the main party to oppose them were the Communist Party of India and other leftist parties alliances to them.', 'Some may want to get every word exactly right while other children will race to the end of a story .', 'At that time in rajsabha lord shri Krishna showed his ultimate wide vishwaswaroop and made everyone scare.', 'Demand was increasing fast and the mills had to switch over to two-shift working , utilising available idle capacity .', "prior to 14th century,country's maximum area got captured in single state", 'In Indian culture, Holy texts have a special importance, and the Purans are among the most important of all the holy texts.', 'Fast track courts- These are special courts which have been started with a purpose to quickly proceed with long pending criminal cases or under-trial disputes.', 'permanent, billowing, voluptuous forms', 'Other sounds like chirping , rasping , squeaking , whistling and shrieking are deliberately produced by various insects , either as expressions of joy of living or as a means of communication with their friends or warnings to enemies .', 'Every five years', 'In Burma and Ceylon she intends to hold on as long as she can .', "Vishnusahastranam - Glory of Vishnu's 1000 names in Shantiparva.", 'It worked .', 'The number of technically qualified persons employed was inadequate , and the general rank and file of the workers was employed largely on a temporary basis , which was not conducive to greater efficiency .', 'The blue and the dim', 'Although , the Superintendent of the jail and most of the other local officials were reasonable and avoided giving trouble , the Bengal Government who were ultimately responsible for the prisoners were extremely vindictive and the Government of India entirely indifferent .', 'So we light our buildings with daylight.'), ('किंतु इसी बीच दूसरे प्रदेशों से विशेष रूप से दक्षिण से बड़ी संख्या में लोग इन द्वीपों में आ गये , उनमें कुछ अन्य लोग विभिन्न परियोजनाओं के आधार पर यहां बसाये गए ', 'मुझे लगता है कोई भी बुद्धिमान जीवन इस बात को मानेगा कि', 'छोटे छोटे शिशु उद्योग इस समय के मुखऋ-ऊण्श्छ्ष्-य शिशु उद्योगों में चीनी , कागज और दियासलाऋ की चर्चा की जा सकती है ', '२ सूरसारावली', 'बागान की अपेक्षा इसमें मशीनों के अधिक उपयोग के बावजूद , कोयला खदान के काम को फैक़्ट्री प्रणाली के रूप में कम संरक्षण प्राप्त था ', 'हालंकि , ब्रिटेन जैसे देश के इस तरह खुलेआम कानून बनाने से कूटनीतिक तौर पर तो मदद मिलती है , लेकिन महत्वपूर्ण यह है कि इससे , मान ल कश्मीर में , बगावत पर क्या असर पड़ैगा ', 'सूखे धुंध को बनाने के लिए', 'इनमें प्रमुख हैं फ़रक्का बाँध टिहरी बाँध तथा भीमगोडा बाँध।', 'मलेरिया के मुकाबले।', 'जब ये अंतरिक्ष प्रतिस्पर्धा पूरे ज़ोर पर था', 'शायद कुछ ऐसी समस्याएँ हों , जिनके बारे में आप न जानते हों ', 'दस साल की उम्र में मुझे जबरदस्ती अखबार बेचना भेज दिया गया ।', 'धार्मिक नेता इसके प्रति पूरी तरह से सजग थे तथा सभी तरह के भेद भाव को समूल उ ...

# %%
from torch import nn

criterian = nn.CrossEntropyLoss(ignore_index=hindi_to_index[PADDING_TOKEN],
                                reduction='none')

# When computing the loss, we are ignoring cases when the label is the padding token
for params in transformer.parameters():
    if params.dim() > 1:
        nn.init.xavier_uniform_(params)

optim = torch.optim.Adam(transformer.parameters(), lr=1e-4)
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
NEG_INFTY = -1e9

def create_masks(eng_batch, kn_batch):
    num_sentences = len(eng_batch)
    look_ahead_mask = torch.full([MAX_SEQUENCE_LENGTH, MAX_SEQUENCE_LENGTH] , True)
    look_ahead_mask = torch.triu(look_ahead_mask, diagonal=1)
    encoder_padding_mask = torch.full([num_sentences, MAX_SEQUENCE_LENGTH, MAX_SEQUENCE_LENGTH] , False)
    decoder_padding_mask_self_attention = torch.full([num_sentences, MAX_SEQUENCE_LENGTH, MAX_SEQUENCE_LENGTH] , False)
    decoder_padding_mask_cross_attention = torch.full([num_sentences, MAX_SEQUENCE_LENGTH, MAX_SEQUENCE_LENGTH] , False)

    for idx in range(num_sentences):
      eng_sentence_length, kn_sentence_length = len(eng_batch[idx]), len(kn_batch[idx])
      eng_chars_to_padding_mask = np.arange(eng_sentence_length + 1, MAX_SEQUENCE_LENGTH)
      kn_chars_to_padding_mask = np.arange(kn_sentence_length + 1, MAX_SEQUENCE_LENGTH)
      encoder_padding_mask[idx, :, eng_chars_to_padding_mask] = True
      encoder_padding_mask[idx, eng_chars_to_padding_mask, :] = True
      decoder_padding_mask_self_attention[idx, :, kn_chars_to_padding_mask] = True
      decoder_padding_mask_self_attention[idx, kn_chars_to_padding_mask, :] = True
      decoder_padding_mask_cross_attention[idx, :, eng_chars_to_padding_mask] = True
      decoder_padding_mask_cross_attention[idx, kn_chars_to_padding_mask, :] = True

    encoder_self_attention_mask = torch.where(encoder_padding_mask, NEG_INFTY, 0)
    decoder_self_attention_mask =  torch.where(look_ahead_mask + decoder_padding_mask_self_attention, NEG_INFTY, 0)
    decoder_cross_attention_mask = torch.where(decoder_padding_mask_cross_attention, NEG_INFTY, 0)
    return encoder_self_attention_mask, decoder_self_attention_mask, decoder_cross_attention_mask

# %%
hindi_sentences
# Out:
# ['राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह करने कि अनुमति नहीं है ',
#  'मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहूंगी',
#  'यह प्रतिशत भारत में हिन्दुओं प्रतिशत से अधिक है।',
#  'हम ये नहीं कहना चाहते कि वो ध्यान नहीं दे पाते',
#  'इन्हीं वेदों का अंतिम भाग उपनिषद कहलाता है।',
#  'कश्मीर के तत्कालीन गवर्नर ने इस हस्तांतरण का विरोध किया था , लेकिन अंग्रेजों की सहायता से उनकी आवाज दबा दी गयी ',
#  'इसमें तुमसे पूर्व गुज़रे हुए लोगों के हालात हैं।',
#  'और हम होते कौन हैं यह कहने भी वाले कि वे गलत हैं',
#  'हो सकता है कि आप चाहते हों कि आप का नऋर्नमेनटेन्ड ह्यबिना किसी समर्थन के हृ विशेष स्कूल , या किसी स्वतंत्र स्कूल में जाए , इजसके पास विशेष शैक्षणिक जऋऋरतों वाले बच्चों के प्रति सहूलियत हों . ',
#  'कृपया यह सुनिश्चित कर लें कि आप सही फॉर्म का प्रयोग कर रहें हैं ',
#  'यह काल समग्रतः भक्ति भावना से ओतप्रोत काल है।',
#  'तो वहाँ न्याय है',
#  'पहले दो को अविश्वसनीय मानकर बाकी पांच मुखबिरों के आधार पर मुकदमा चलाया गया ',
#  'हाल में नेपाल के हस्पताल सामन्यतया आयुर्वेद, प्राकृतिक चिकित्सा तथा आधुनिक चिकीत्सा करके सरकारी सेवा विद्यमान हे ।',
#  'लाडड़ी लोकप्रिय स्त्री नृत्य है ',
#  'धीरे धीरे ये सब बदला',
#  'एक ही जीन के उत्परिवर्तन के कारण होने वाले आनुवंशिक रोग इन सभी रोगों से अधिक महत्वपूर्ण हैं.मेंडेल के सरल वितरण के नियम के अनुसार यह जीन संतानों में प्रकट होता है ',
#  'उत्पन्न नहीं कि जाती थी',
#  'नरेंद्र ने कौंसिल से तीन या चार मुलाकातें की किंतु उन्होनें महसूस किया कि वे किसी भी प्रकार से बात आगे नही बढ़ा पा रहे है ',
#  'जो भी इस झंडे के नीचे खड़ा है वह न हिंदू है , न मुसलमान , बल्कि वह हिंदुस्तानी है ',
#  'कुछ मामलों में प्रथम स्तर के न्यायालय होने के कारण उच्च न्यायालयों को उच्चतम न्यायालय की अपेक्षा मामलों पर अधिक कारगर ढंग से कार्रवाई करने की अधिकारिता है ',
#  'और जैसा आप देख रहे है, ये एल.ई.डी. जल उठेगी।',
#  'अधिनियम के अधीन एक से अधिक दावा अधिकरण स्थापित किए जा सकते हैं और उनकी अधिकारिता को अधिकरणों के गठन की अधिसूचना में विनिर्दिष्ट कर दिया जाता है ',
#  'लाईट जलाने के लिए या उनके लिए पानी लाने के लिए',
#  'मेन',
#  'फारसी रहस्यवाद में मुगल कालीन इस्लामी पाठ्य में फिरदौस को एक आदर्श पूर्णता का बाग बताया गया है।',
#  'क्या आप ये कल्पना कर सकते है',
#  'जिंदा रहने के लिए जूँ किसी जीव के सम्पर्क में रहना आवश्यक है',
#  'मगर उनके निधन के पश्चात उनके भाई सरदार वल्लभ भाई पटेल ने इस वसीयत को स्वीकार नहीं किया और उसपर अदालत में मुकदमा चलाया।',
#  'उन्होनें बड़े दुख के साथ यह भी देखा कि कैसे छठी कमिन्टर्न कांग्रेस की अतिवामपंथी मार्ग अपनाकर साम्यवादियों ने अपने को नष्ट कर लिया था और वामपंथी आंदोलन को भी बढ़ते देखा था ',
#  'ग्रामीण चीन में आर्थिक नवीनीकरण हुये हैं।',
#  'यह इस कहानी का अंतिम सबक है ',
#  'इसमें टकरवा ही टकराव है - नए के साथ पुराने का , राज्य सत्ता बनाम आदर्शवाद का , साध्य और साधन का , अधिकार पूर्ण प्रेम और प्रेम की स्वतंत्रता का , और बाहरी जंगली हवा के साथ ग्राहस्थिक या घरेलू मूल्यों का ',
#  'अपने प्रगतिशील विचारों के कारण उन्होंने विधवा-विवाह और कन्याओं की विवाह योग्य आयु-सीमा बढ़ाने की भी वकालत की ',
#  'विश्लेषण और विवेचन बड़े गंभीर और सरस थे और शैली इतनी मोहक थी कि सारा-का-सारा लेखन साहित्य का उत्कृष्ट निदर्शन बन गया ',
#  'वियतनाम में परिवार योजना शुरू हो गई और उनके परिवार छोटे होने लगे।',
#  'मेरा मतलब, उस समय, सही मानिए',
#  'जयेंद्र सरस्वती के लिए अध्यात्म कभी कोई स्थिर चीज नहीं रही है ',
#  'बस वही नहीं',
#  'जिसे हम प्रवृत्ति कहते हैं और जिसे हम अपने दैनंदिन जीवन में बहुत तुच्छ समझ कर नकार दिया करते हैं- यही वह चीज है जो हमें सदगुणों या दुर्गुणों के अरण्य से बाहर निकालने में सहायक बनकर हमारी नियति की असीम संभावनाओं तक और हमारी चेतना एवं उल्लास तथा अनुताप तक ले जाती है ',
#  'मानवों ने उन ही साझे संसाधनों को नष्ट किया जिन पर वो आधारित थे।',
#  'रचना करीब करीब ई तक जाती है, मगर तब तो नाटक ख़त्म हो जाएगा',
#  'आर्य देवताओं की कोई मूर्ति या मन्दिर नहीं बनाते थे।',
#  'यह एक छोटी तीन गुम्बद वाली तराशे हुए श्वेत संगमर्मर से निर्मित है।',
#  'महात्मा गांधी के साथ सरोजिनी नायडू',
#  'बाहरी कड़ियाँ',
#  'पिछली दीवार पर एक विशेष ताक में , एक सामान्य सोमस्कंद फल्क उकेरा गया है , जिसमें शिव और उमा बैठे हुए हैं , नन्हाँ स्कंद उमा की गोद में हैं और दोनों और ब्रह्मा और विष्णु खड़े हैं ',
#  'मैं आपके साथ कुछ मुख्य सूत्र बाँटना चाहता हूँ',
#  'फ्रांस , बेलजियम , जर्मनी , संयुक्त राज्य अमेरिका , रूस और बाद में जापान ने अपने यहां शक्तिशाली उद्योगों का विकास किया और अपने माल की खपत के लिए विदेशी बाजार की खोज शुरू की ',
#  'पर अगर आप व्यापारी को अधिक समय देना स्वीकार करते हैं , तो आप इस समय के बीत जाने के पहले अपना आर्डर रद्द नहीं कर सकते ',
#  'यह परिवर्तन योगदान दे रहा है',
#  'हमने समस्या का हल निकालने का ज़िम्मा पूरे समुदाय पर डाल दिया',
#  'अल्पकाली उद्देश्य रेखांकित करने का प्रबंध करना एवं उन उद्देश्यों के प्रति आप की नियमित उन्नति का निरीक्षण करें ',
#  'वे बहुधा उनसे मिलने की तीव्र इच्छा के बारे में भी हमें बताया करते ',
#  'इस सकारात्मक अर्थबोध में स्वतंत्रता का अर्थ होगा किसी व्यक्ति की अपनी इच्छा के अनुसार कार्य करने की स्वतंत्रता ',
#  'इसके प्रभाव को बहुत ही कम आंका गया है।',
#  'उस गुरुभाई को पाठ पढ़ाते हुए और गुरुदेव की प्रत्येक वस्तु के प्रति प्रेम दर्शाते हुए उनके बिस्तर के पास रक्त कफ आदि से भरी थूकदानी उठाकर फेकते थे।',
#  'कैरियर होटल',
#  'हमारी आखो के लिए अलग बनावट और अलग रंग के हैं ',
#  'वित्त व्यवस्था पर संसद का नियंत्रण',
#  'किंतु इसी बीच दूसरे प्रदेशों से विशेष रूप से दक्षिण से बड़ी संख्या में लोग इन द्वीपों में आ गये , उनमें कुछ अन्य लोग विभिन्न परियोजनाओं के आधार पर यहां बसाये गए ',
#  'मुझे लगता है कोई भी बुद्धिमान जीवन इस बात को मानेगा कि',
#  'छोटे छोटे शिशु उद्योग इस समय के मुखऋ-ऊण्श्छ्ष्-य शिशु उद्योगों में चीनी , कागज और दियासलाऋ की चर्चा की जा सकती है ',
#  '२ सूरसारावली',
#  'बागान की अपेक्षा इसमें मशीनों के अधिक उपयोग के बावजूद , कोयला खदान के काम को फैक़्ट्री प्रणाली के रूप में कम संरक्षण प्राप्त था ',
#  'हालंकि , ब्रिटेन जैसे देश के इस तरह खुलेआम कानून बनाने से कूटनीतिक तौर पर तो मदद मिलती है , लेकिन महत्वपूर्ण यह है कि इससे , मान ल कश्मीर में , बगावत पर क्या असर पड़ैगा ',
#  'सूखे धुंध को बनाने के लिए',
#  'इनमें प्रमुख हैं फ़रक्का बाँध टिहरी बाँध तथा भीमगोडा बाँध।',
#  'मलेरिया के मुकाबले।',
#  'जब ये अंतरिक्ष प्रतिस्पर्धा पूरे ज़ोर पर था',
#  'शायद कुछ ऐसी समस्याएँ हों , जिनके बारे में आप न जानते हों ',
#  'दस साल की उम्र में मुझे जबरदस्ती अखबार बेचना भेज दिया गया ।',
#  'धार्मिक नेता इसके प्रति पूरी तरह से सजग थे तथा सभी तरह के भेद भाव को समूल उखाड़ने में सक्रिय थे ',
#  'उनका विरोध करने वालों में उस समय सबसे मुख्य दल भारतीय कम्यूनिस्ट पार्टी और अन्य वामपंथी सहयोगी दल थे।',
#  'हो सकता है कि कुछ बच्चे प्रत्येक शब्द बिलकुल सही पढ़ना चाहते हो जबकि अन्य कहानी के अंत तक पहुँचने की होड़ में रहेंगे ',
#  'उस समय राजसभा में भगवान् श्रीकृष्ण ने माया से अपने परम दुर्धर्ष विश्वरूप का दर्शन कराकर सबको भयभीत कर दिया।',
#  'मांग तेजी से बढ़ रही थी और मिलों ने उपलब्ध क्षमता का उपयोग करते हुए दो पारी में काम करना शुरू कर दिया ',
#  '१४वीं शताब्दी के उत्तरार्ध मे देश का बहुत ज्यादा भाग एकीकृत राज्य के अधीन में आ गया।',
#  'भारतीय जीवन-धारा में जिन ग्रन्थों का महत्वपूर्ण स्थान है उनमें पुराण भक्ति-ग्रंथों के रूप में बहुत महत्वपूर्ण माने जाते हैं।',
#  'फास्ट ट्रेक कोर्ट - ये अतिरिक्त सत्र न्यायालय है इनक गठन दीर्घावधि से लंबित अपराध तथा अंडर ट्रायल वादों के तीव्रता से निपटारे हेतु किया गया है',
#  'स्थायी, तरंगित, आकर्षक, बड़ी इमारतो के आकार के',
#  'विभिन्न कीट चींचीं , खड़खड़ , किकियाने , सीटी और कर्कश चीख जैसी आवाजें पैदा करते हैं.ऐसा या तो जीवन के आनंद की अभिव्यक़्ति के रूप में या अपने मित्रों से संपर्क करने के साधन के रूप में या शत्रुओं को चेतावनी देने के लिए करते हैं ',
#  'हर पाँच साल में',
#  'बर्मा और सीलोन पर वह जब तक हो सकता हैं , अपना कब्जा बनाये रखना चाहता',
#  'विष्णुसहस्रनाम विष्णु के १००० नामों की महिमा शांतिपर्व में।',
#  'और यह तरीका कारगर रहा ',
#  'तकनीकी व्यक़्तियों की संख़्या भी कम थी और अधिकांश श्रमिक भी अस्थायी तौर पर नियुक़्त थे जो कि अधिक कार्यक्षमता की दृष्टि से लाभप्रद नहीं था ',
#  'नीले और मंद',
#  'हालांकि जेल-अधीक्षक तथा अन्य अधिकांश स्थानीय अधिकारियों का रवैया ठीक था,लेकिन बंगाल सरकार का रवैया , जो कि अपने कैदियों के भले-बुरे की खासतौर पर जिम्मेदार थी , प्रतिशोधपूर्ण था और भारत सरकार इस सबसे एकदम निस्पृह थी ',
#  'तो हम अपनी इमारतों को दिन के उजाले से प्रकाशित करते हैं',
#  'कहाँ , कब, वेब्साइट।',
#  'और वह है कि उनके बच्चे कामयाब निकलें',
#  'मैथुन',
#  'इसके चलते सुप्रीम कोर्ट ने खुद कुछ बन्धन इनके प्रयोग पे लगाये है',
#  'विश्व के बारे में चिंपैंजी से भी कम जानते हैं।',
#  'तीनों ही अपनी योजनाओं और प्रस्तावों को सामने रखने के मामले में',
#  'मसलन , कोका कोल कंपनी अब सार्वजनिक निर्गम लने से छूट चाहती है ',
#  'शरद जोशी और बिपिन देसाई सरीखे दिग्गज नेताओं की अगुआई में किसानों ने सरकार को धमकी दी कि अगर उसने फसल नष्ट की तो गंभीर नतीजे भुगतने होंगे ',
#  'अगर आप आकर्षक हैं तो ऐसा हो सकता है ',
#  'रॉयल चितवन राष्ट्रीय उद्यान',
#  'यानी ह्क्का गुड़ेगुड़ने वालं के पास बातचीत के कई मुद्दे होंगे ',
#  'यह मौका था एक अहम शुरुआत की वर्षगां मनाने का , लेकिन फूलन देवी की हत्या और यूटीआइ घोटाले को लेकरौ उ ए बवाल पर प्रधानमंत्री की इस्तीफे की नाटकीय घोषणा के शोरशराबे के चलते इस पर किसी ने ध्यान नहीं दिया ',
#  'इस प्रकार एक बार स्थिति बदल लेने से एक रन बन जाता है।',
#  'दमयन्ती अथवा नल दमयन्ती अरण्यकपर्व में एक प्रेमकथा।',
#  'इससे पहले एबीसीएल के बुरी तरह असफल हो जाने से अमिताभ को गहरे झटके लगे थे।',
#  'आप हमें यह भेजें ',
#  'पहाड़ों में ऊपर थे और फेय्न्मन ने मुझसे कहा',
#  'नियमों में यह स्पष्ट उल्लेख है कि राजा को बड़ी सावधानी के साथ वादों का विचारण करना चाहिए और न्यायाधीशों की राय मानते हुए विधि के अनुसार निर्णय देना चाहिए ',
#  'लोग नए-नए वस्त्र सिलवाते हैं।',
#  'गुरु ने जैसे ही एक कंगन उठाया , वह उनके हाथ से फिसलकर नीचे नदी में गिर पड़ा ',
#  'सचाई इसी अति उदासीनता और अतिशय प्रतिक्रिया के बीच कहीं छिपी ही है और उसी के ऊपर बंगाल के निर्दोष नागरिकों का भविष्य अटका हा है ',
#  'हमने उनकी आलोचना की',
#  'बकरी के दूध की विशेष गन्ध के कारण अनेक लोगों में इसके प्रति अरुचि होती है ',
#  'वे हिन्दुस्तान सोशलिस्ट रिपब्लिकन एशोसिएशन के स्थापक सदस्यों में से एक थे।',
#  'ये पीठे क्षेत्र के राज नैतिक दबाव मे आ जायेगी',
#  'सृ्ष्टि के अवशेषों के माध्यम से यह अनुमान लगाने का प्रयास करेंगे कि आरंभ में क्या हुआ था',
#  'विश्व सुधार अत्यधिक प्रासंगिक होना चाहिए',
#  'इन शहरों में ज़्यादा तोड-फोड़ नहीं हुई दिखती , लेकिन इन शहरों में वह चहल-पहल कहां जो पहले होती थी ',
#  'अमोनिया उड जाती है',
#  'वो समकालीन आंकडें लेते हैं',
#  'वर्ल्ड गैज़ेटियर द्वारा २००८ में किये गये गणना कार्यक्रम के अनुसार मुंबई की जनसंख्या १३६६२८८५ थी।',
#  'कि आपके पास हमेशा दो विकल्प होने चाहिए',
#  'काफी हद तक उसे निष्पक्षता की वही भूमिका निभानी होती है जो अध्यक्ष निभाता है ',
#  'ग्रन्थसूची',
#  'इस अवसर पर दिए गए उनके भाषण में उनके इस गुण को देखा जा सकता है।',
#  'अनऋ-ऊण्श्छ्ष्-य प्रकार भिनऋ-ऊण्श्छ्ष्-न भिनऋ-ऊण्श्छ्ष्-न समयों पर होने वाले उतऋ-ऊण्श्छ्ष्-सवों के लिए उतऋ-ऊण्श्छ्ष्-सव मंडप हैं , जहां उतऋ-ऊण्श्छ्ष्-सव मूर्तियां सजाऋ जातीं , पूजी जातीं और जुलूस के रूप में बाहर लाऋ जातीं ',
#  'इन कारीगरों को अपने काम के लिये नकद भुगतान नहीं होता था.वरन् फसल के बाद परंपरागत तरीके से उत्पादन का एक निश्चित हिस्सा मिलता था ',
#  'इस संबंध में जब लार्ड कर्जन से सलाह ली गई तो उन्होंने बताया कि भारत में ऐसे कई लोग हैं जो रवीन्द्रनाथ से कहीं अधिक महत्वपूर्ण हैं ',
#  'तब आरंभिक बीसवीं शताब्दी में यहां सबसे पुरानी फिल्म प्रसारित हुयी थी।',
#  'लंबा-चौड़ा यही मुल्क हम सबके लिए , जो यहां रहते हैं , हिंदुस्तान है , भारत माता है ',
#  'पिर . . ..भी , उनका कोई एक अखिल भारतीय संवर्ग नहीं है ',
#  'दुनिउया का लोकशाही केंद्र',
#  'बुनकरों को अपनी और आकर्षित करने की होड़ में बंगाल मिलों ने इतनी मजदूरी देनी शुरू की जो दूसरे बुनाई उद्योगों के लिए देना असंभव था और परिणामस्वरूप इन उद्योगों को बंगाल से बाहर जाना पडा ',
#  'परंतु यदि कोई दोष जन्म के तुरंत बाद दिखाई देने लगता है तथा इतना गंभीर होता है कि रोग पीड़ित व्यक्ति प्रजनन के योग़्य नहीं रहते तो उन व्यक्तियों का बंध्याकरण उचित नहीं लगता हंसिया रोग इसी तरह की एक रोग है ',
#  'अपनी गलतियों के बारे में सोचने से बचने के लिए',
#  'संस्कृत_ओसीआर से प्राप्त रोमन आउटपुट को देवनागरी में बदलने का दूसरा प्रोग्राम',
#  'शिक्षा , बुद्धि चरित्र और उपलब्धि के मामलों में उनकी तुलना केवल सर्वोच्च अंग्रेज राजनेता से की जा सकती है , जबकि कोई भी भारतीय क्षण भर के लिए भी संदेह नहीं कर सकता कि सार्वजनिक जीवन में उनके शामिल होने का एक मात्र लक्ष्य मातृभूमि के प्रति उनकी संबंद्धता और उनका प्रेम था ',
#  'कमाल है',
#  'अधिक अवधि के लिए किये जाने वाले व्यायाम के दौरान तथा उसके बाद रक़्त में ग़्लूकोज की मात्रा काफी कम हो सकती है ',
#  'एक और दो पालक वाले परिवार ',
#  'लडकियों को स्कूल कैसे भेजा जा सकता था क़्योंकि इसका अर्थ होता सार्वजनिक स्थानों से गुजरना और पुरूषों से संपर्क ',
#  'इसी बीच गेंदबाज की टीम के अन्य सदस्य मैदान में क्षेत्ररक्षक के रूप में अलग अलग स्थितियों में खड़े रहते हैं ये खिलाड़ी बल्लेबाज को दौड़ बनाने से रोकने के लिए गेंद को पकड़ने का प्रयास करते हैं और यदि सम्भव हो तो उसे आउट करने की कोशिश करते हैं।',
#  'और अपनी पहचान को बदलते भी रह सकते हैं',
#  'नियमित शारीरिक कसरतों से वजन नियंत्रण में रहता है तथा रक्त का संचरण एवं हृदय का संचालन भी सुचारु रूप से होता है ',
#  'और क्योंकि मुझे ये अजीब लगा था, मैं उनसे मिलने चली गयी',
#  'यह कहानी चल रही है. आदान-प्रदान की कला.आप मुझ से बात कर सकते हैं',
#  'मैं नहीं कह रहा कि यह बिल्कुल नहीं पहुँच रहा।',
#  'आश्विन शुक्ल दशमी को विजयादशमी का त्यौहार मनाया जाता है।',
#  'जो अफगानिस्तान के निकट है, की अोर संकेत करते हैं',
#  'इन व्यक्तियों की नियुक्ति केंद्र सरकार द्वारा की जाती है और ये अपने नियुक्ति आदेश में उल्लिखित अवधि के लिए पद धारण करते हैं , पर यह अवधि पांच वर्ष से अधिक नहीं हो सकती ',
#  'हिमालय के ऊपरी भाग में इसमें टोंस तथा बाद में लघु हिमालय में आने पर इसमें गिरि और आसन नदियाँ मिलती हैं।',
#  'इसके लिए अभी और चिकित्सकीय परीक्षणों की जरूरत है ',
#  'वीडियो रैंकिंग',
#  'और कुछ अवसादपूर्ण हैं, जैसे नाइजीरिया में',
#  'परिणाम कुछ हास्यकारक हो सकते हैं',
#  'सम्भवतः तिब्बती-बर्माई मूल के लोग नेपाल मे २५०० वर्ष पहले आ चुके थे।',
#  'इसलिए आधुनिक फैक़्ट्री निर्माता के रूप में इसका पुनर्जन्म , भरतीयों के लिए उज़्ज़्वल भविष्य के दर्शन के साथ अतीत के गौरव का पुनरूत्थान था ',
#  'और अंत में , ऊर्जा के वैकल्पिक स्रोतों की वास्तविक सामाजिक लागत को दर्शाते तर्कसंगत ऊर्जा , मूल्यों के निर्धारण की केवल बातें ही होती रही हैं काम कुछ नहीं हुआ है ',
#  'ऐसे डीलर से सावधान रहिए जो किसी कार के इतिहास को गुप्त रखने की कोशिश करता हुआ आए ',
#  'लोगों को एक चीज़ को सूँघने से रोकना , हो सकता है उन्हें उन पदार्थों को सूँघने की ओर मोड़ दे , जो ज़्यादा ख़तरनाक होंगे ',
#  'जो मैंने करीब एक साल पहले लगाया था -',
#  'यही कारण है कि वह गिरता है',
#  'और मुझे समझ आया कि धैर्यवान पूँजी की भावात्मक महत्ता क्या है',
#  'तो अमी तबर ने इसे एक एकड के आठवें भाग जितने बडे खेत में लगाने लायक बनाया।',
#  'बाहरी कड़ियाँ',
#  'यह छात्र, शायद पहली बार इसे उपयोग कर रहा है, एक जटिल हस्त कौशल का काम कर रहा है',
#  'और उन्हें बार बार आश्र्वासन दें कि सभी कुछ ठीक हो जायेगा ',
#  'पहले पैरिस और लन्दन और न्यू योर्क दुनिया के सबसे बड़े शहर हुआ करते थे',
#  'तो आदमी आज भी एक लकड़ी जला कर आग के सामने',
#  'हम उन्हें ब्राउज़िंग और एक दूसरे को ब्राउज़ करना सिखाते पाया।',
#  'उत्तेजित भीड़ द्वारा विदेशी कपड़ों की होली जलाना और उस पर खुश होने से उन्हें नफरत थी.विद्यार्थियों को स्कूल और कालेज छोड़कर राजनीतिज्ञों के हाथ का खिलौने बनने पर भी वे बहुत दुखी थे ',
#  'बहुत खतरनाक हो सकता है ',
#  'अस्तबल इस तरीके से बनाये जाने चाहिएं कि खराब मौसम , अत्यधिक गर्मी , ठंड और वर्षा से उनका बचाव हो जाये ',
#  'अतः उनकी परीक्षा करने के लिये द्रुपद ने उन्हें अपने राजप्रासाद में बुलाया।',
#  'मतलब, मैं कहती रही हूँ कि मैं तैयारी कर रही हूँ',
#  'बच्चन के श्रेष्ठ कविताओं का संकलन',
#  'हिन्दुओं का कोई केन्द्रीय चर्च या धर्मसंगठन नहीं है और न ही कोई पोप।',
#  'एक पंछी की तरह उड़ान भरना',
#  'यहां तक कि स्वदेशी वालं के लिए सबसे पवित्र क्षेत्र रक्षा उत्पादन को भी कुछ किंतु-परंतु के साथ खोल दिया गया है ',
#  'मुजफ्फरपुर',
#  'हनुमान ने अशोकवाटिका का विध्वंस करके रावण के पुत्र अक्षय कुमार का वध कर दिया।',
#  'भारत के लिए चावला की आखिरी यात्रा १९९१-१९९२ के नए साल की छुट्टी के दौरान थी जब वे और उनके पति परिवार के साथ समय बिताने गए थे।',
#  'यह है भारत, और बेशक इससे भी ज्यादा अचंभित करने वाला है',
#  'दिल्ली खामोशी का जामा संसद के गहमागहमी भरे मानसून सत्र के दो हते बाद भी विपक्ष की नेता सोनिया गांधी अभी तक सुर्खियों में नहीं आईं ',
#  'धातुखंड पर टकसाल की मोहर होने से ही बाहर उसकी सिक़्के के रूप में स्वीकृति है ',
#  'ध्यान रखें कि इन मानकों को प्राप्त न करने का कनाडा में कोई महत्व नहीं है',
#  'शरियत की निति को नींव बना कर न्यायशास्त्र के अध्य्यन को फिक़ह कहते हैं।',
#  'जब मेरे माता-पिता कनाडा आये',
#  'कि उन्हें अपने ही पैरों पर खड़े करने के लिए मदद करें।',
#  'शिशिर गुप्त अ आरह सौ सत्तावन की आजादी की पहली लड़ई के बाद अंदमान-निकोबार द्वीप समूह अंग्रेज सरकार के लिए कैदियों को काल पानी की सजा देने की जगह थी ',
#  'दर्शनीय स्थल',
#  'उन रिपोर्टों के बारे में कहा जाता है कि ये शार्टहैंड से ली गयी हैं , लेकिन ये रिपोर्टें मुकम्मिल नहीं , ये अधूरी हैं , ये साफ नहीं हैं और कहीं कहीं से तो कोई मायने भी नहीं निकलते हैं ',
#  'तत्पश्चात उन्हें उठाकर घर में सभी स्थानों पर रखा जाता है ',
#  'इसी कारण पौधों का विकास पृथक रूप में होकर उनके बाह्य रूप भिन्न हो जाते हैं ',
#  'बाह्य रूप से चतुर्भुज खुला प्रांगण एक प्राकार से घिरा होता है जिसमें एक विहार , या मालिका होती है जिसे स्थानीय रूप से नलांबलम या चुट्टांबलम कहा जाता हैं ',
#  'वे सुस्थापित रूप हैं जो इतनी अच्छी तरह से अनुकूलित हो गए हैं कि अपने ग्रामीण संबंधियों के पास आकस्मिक रूप से जाने का न तो प्रयास करते हैं और न जा ही सकते हैं ',
#  'न्यायाधीश , एडवोकेट जनरल , सैन्य अफसर और राजनीतिक नेतासभी इस यादगार बयान को कान लगाकर ध्यान से सुन रहे थे ',
#  'गुम्बद एवं छतरियों के शिखर पर परंपरागत फारसी एवं हिंदू वास्तु कला का प्रसिद्ध घटक एक धात्विक कलश किरीटरूप में शोभायमान है।',
#  'कभी कभी आंखें और नाक पीले रंग के पनीले स्राव से ढंप जाती हैं ',
#  'अगला मण्डप है दीवान-ए-खास जो राजा का मुक्तहस्त से सुसज्जित निजी सभा कक्ष था।',
#  'कबीर के राम इस्लाम के एकेश्वरवादी एकसत्तावादी खुदा भी नहीं हैं।',
#  'लेकिन इससे भी बड़ी विपत्ति इस उद्योग पर अभी आने वाली थी ',
#  'वे सही रास्ते पर नहीं चल रहे हैं',
#  'स्थान कम रह गया था।',
#  'ऐसे भी बाक्स पाचक विकसित किए गये हैं जो बरसात या धुंध के दिनों में बिजली से खाना पकाने हेतु प्रयोग किए जा सकते हैं।',
#  'यह युद्ध हजरत मुहम्मद सल्लल्लाहु अलैहि वसल्लम के ज़माने से चली आ रही दुश्मनी का हिस्सा थे।',
#  'भारत मे अंतरजाल',
#  'बहरहाल वह अपने इस सिद्धांत के द्वारा यह सिद्ध करना चाहता था कि अंडाणु का आधा भाग पृथ्वी के रूप में फैल गया और दूसरा आधा गुंबज की भांति उसके ऊपर स्थापित हो गया और इसमें भू-मंडल के तल-प्रक्षिप्त गोल के विवेचन में वह टॉल्मे का स्पर्धी बनना चाहता था , किंतु विफल रहा ',
#  'तमिळ',
#  'वह बदबू ज्होलकर बाबुओं की भीड़े को चीरते हे आप गलियारों में दाखिल होते हैं और उसके बाद आता है गर्भगृह यानी बड़े साहब का कमरा ',
#  'और यह मजबूत हो रही है ',
#  'लेकिन जब दकियानूसी ताकतों , तानाशाही और साम्राजऋ-ऊण्श्छ्ष्-यवाद की हार होने लगती है , तब बात अहम ढहो जाती है और इन संधियों को बरकरार रखने की पूरी कोशिश की जाती है , चाहे ये कितनी ही पुरानी क्यों न हों और इनसे जनता का चाहे ऋतना भी नुकसान कऋ-ऊण्श्छ्ष्-यों न होता हो ',
#  'रीवा',
#  'वे १८९५ में उच्च शिक्षा प्राप्त करने के लिए इंग्लैंड गईं और पढ़ाई के साथ-साथ कविताएँ भी लिखती रहीं।',
#  'प्रारम्भ में इस नहर में जलापूर्ति गंगा नदी में एक अस्थायी बॉंध बनाकर की जाती थी।',
#  'निर्वाण प्राप्त करना',
#  'अर्थात जब माया के आइने में ब्रह्म की छाया पड़ती है तो ब्रह्म का प्रतिबिम्ब हमें ईश्वर के रूप में दिखायी पड़ता है।',
#  'तो यह पथ रेखाएं दर्शाती हैं कि हमारी अपेक्षा में लोग कैसे जियेंगे',
#  'संसार की अधिकाश ऊँची पर्वत चोटियाँ हिमालय में ही स्थित हैं।',
#  'नेवाडा',
#  'धन्यवाद।',
#  'मगर यदि आप इंगलिश के मूल-वक्ता नहीं हैं',
#  'परिणामस्वरूप , अत्यधिक उन्नत किस्मों के उत्पादन में वृद्धि हो रही थी.यद्यपि भूमि क्षेत्र कम हो रहा था ',
#  'अगली उपलब्धि है उस एक करोड़ को आधा करना',
#  'अगर हम चाहते तो अपनी बात मनवाकर पाकिस्तान को उस पर राजी करवा सकते थे ',
#  'वह मुसलमानों के प्रवक़्ता बने रहे और जानते थे कि जहां कहीं भी उसकी वैध शिकायतें हों , मुसलमानों द्वारा अन्य लोगों सेप्राप्त सहायता या सहानुभूति केवल मरहम हो सकती है , रोगमुक़्त नहीं कर सकती ',
#  'होड़ चली है',
#  'यदि हम खरीद पाने लायक मूल्य में उन्हें साहित्य उपलब्ध कराएं',
#  'नेहरू को छोड़कर और किसी भी राष्ट्र नेता के मन में यह चिंता नहीं थे ',
#  'अब तक उस पल तक',
#  'को सीखने के लिए खुला रख पाएँ,हो सकता है हम अपने दिमागों',
#  'क्योकि सारी जानकारी, डीएनए के अंदर है',
#  'अगर नाइकी एक जोडी जूते बेचना चाहता और',
#  'वहाँ पर बैठे हुए, किसी व्यक्ति की तरफ देखते हुए, और उनके कहीं और देखने का इंतेज़ार कर रहे हैं',
#  'इनके लिए साफ और ताजे जल की सदैव व्यवस्था होनी चाहिए ',
#  'छेड़े जाने या डराए जाने पर यह भृंग अपनी गुदा के सिरे से एक दुर्गंधयुक़्त और दाहक वाष्पशील द्रव जोरदार धमाके से निकालता है और भाग निकलता है तथा पीछे रह जाता है तीखे धुएं से पराजित एकदम भ्रमित शत्रु ',
#  'फायरफॉक्स हेतु हिन्दी वर्तनी जाँचक ऍडऑन',
#  'अगर आप किसी विदेशी शाखा से अस्थाई तौर पर उस का स्थानांतरण कर दें या किसी विदेशाई नियोक्ता ने उस की आप के पास काम करने की सिफारिश करी है , तो इस के रोज़गार की विदेशी संविदा का ज़ारी रहना ही ठीक रहेगा ',
#  'सरकार ने उसके उत्पादन का बड़ा अंश लगान और अन्य करों के रूप में ले लिया ',
#  'अपने पुलिस के कर्तव्यों के अतिरिक्त कोतवाल को कुछ न्यायिक शक्तियां थीं ',
#  'परंतु वे वास्तव में समाजवादी कम और अराजकतावादी तथा श्रमिक संघवादी अधिक थे ',
#  'मादक पदार्थों की लत हों, तो आप बस और अधिक चाहते हैं',
#  'अंग्रेज़ी हिन्दी शब्दकोष पी॰डी॰ऍफ़॰ प्रारूप में',
#  'अगर मैं इस चक्की को घुमाऊं, तो छोटा वाला तेज़ी से घूमेगा।',
#  'ये असल में मैनें ईरान लौट कर बनाया था',
#  'यह कहा जा सकता है कि ज़्यादातर ये बातें ऊपरी हैं और मूल बातें पकड़ने के लिए हमें वेदों को लेना चाहिए या हमारे दर्शनशास्त्र को ',
#  'जापानी अधिपत्य के पूर्व अंग्रेजी शासनकाल का यहां पर अंतिम पदाधिकारी एक अंग्रेज था जिसका नाम स्कौट था ',
#  'कुछ प्रजातियां ताजे पानी में रहती हैं और पशुओं को काटती हैं जबकि कुछ प्रजातियां अन्य खारे पानी में रहती हैं और मनुष्यों को काटती हैं ',
#  'यकीन करिए या नहीं, ये मैंने सीखे हैं',
#  'हमारे दिमाग में, काम की चीज़ है',
#  'वेद बहुत ही जटिल तथा शुष्क भाषा-शैली में लिखे गए हैं।',
#  'गोल्फ कोर्स और हवाई अड्डे के पास बने इस मंदिर को भगवान का निवास स्थान माना जाता है।',
#  'और मैंने काकी किंग को देखना शुरू किया',
#  'ढाका की मलमल लगातार शताब्दियों तक संसार भर की ईर्ष्या का कारण बनी रही ',
#  'फिर व्यास जी के कहने पर वे पांचाल राज्य में गये जहाँ द्रौपदी का स्वयंवर होनेवाला था।',
#  'आप मेरे साथ २० साल रह सकते है, और कल जा भी सकते हैं।',
#  'इसकी तह में है भारत का आनुवंशिक तौर पर संशोधित पहल बीज , जो बीटी कॉटन के नाम से कुयात है ',
#  'को हुआ होगा, जिसे आप आध्यात्मिक अनुभव कहते हैं',
#  'अयोध्या आंदोलन के मौजूदा दौर में उन आ शहरों पर नजर रखना जरूरी है , जिनका उल्लेख ऊपर बदतरीन शहरों के तौर पर किया गया है ',
#  'संस्कृत का प्राचीन साहित्य अत्यन्त प्राचीन विशाल और विविधतापूर्ण है।',
#  'और ये सब हो रहा है .... इस साल मैं कोशिश करूँगा',
#  'प्रमुख औद्योगिक मशीन समूहों की प्रगति की समीक्षा नीचे दी जा रही है ',
#  'उत्सुक्तावश, कितने आप में से',
#  'डीज़ल इंजन निश्चित रूप से आधुनिक उद्योग , कृषि तथा परिवहन के लिए वरदान सिद्ध हुआ है ',
#  'यह पर्व वर्षमें दो बार मनाया जाता है किन्तु काल क्रम मे अब यह बिहार पूर्वी उत्तर प्रदेश वासियों तक ही सीमित रह गया है।',
#  'उनके मत में इस विकास प्रक्रिया के छह चरण हैं और प्रत्येक अवस्था साधक की मनस्थिति की द्योतक है ',
#  'प्रोस्टेट ट्यूमर गतिविधि लाल रंग से दिखाई गई है -',
#  '२००१ में उसका जीवन बदल गया।',
#  'उनमें मनोहारी साहित्यिक गुण हैं तथा शिव की अनन्य भक़्ति के दर्शन होते हैं ',
#  'इस विलम रिश्ते से एक और नतीजा निकलता है ',
#  'इस क्षेत्र मे ५वी शताब्दी के उत्तरार्ध मे आकर वैशाली के लिच्छवियो के राज्य की स्थापना हुई ।',
#  'पाइलट ने सैनिकों का रेडियो लिया, उनके साहब से बात की',
#  '१९४७ में भारतीय स्वतंत्रता के उपरांत यह बॉम्बे राज्य की राजधानी बना।',
#  'यहां भारत में दिन भर कपड़ै साफ करते , खाना पकाते और साफ-सफाई करते हे जी रही ंं तो मुज्हो भय और आश्चर्य होता है ',
#  'यूरोप प्रस्थान करने से पहले कुछ समय के लिए उन्हें वापस जबलपुर जेल भेज दिया गया था , जहां उनके भैया भी थे ',
#  'यह भी सोचा जा सकता है कि इन में हर एक',
#  "और भी तर्क करते हुए उसने कहा कि ब्राह्मण धर्म ' कर्म का प्रचार करता है भक़्ति का नहीं ",
#  'इसे बीच सोविएत संघ और जापान के बीच में छोटा युध हुआ पर वो लोग अपनी सीमा पर ज्यादा व्यस्त हो गए ।',
#  'वहाँ चलते समय',
#  'इसके साथ टेस्ट क्रिकेट में १२००० से अधिक रन बनाने वाले वे विश्व के एकमात्र खिलाड़ी हैं।',
#  'मुसलमानों को कांग्रेस विरोधी वर्ग , जो मुस्लिम-लीग में शामिल हो गया था , ने कांग्रेस के विरूद्ध अपने समुदाया का भड़काने के लिए विशुद्ध धार्मिक विवाद की अपेक्षा सांस्कृतिक विवाद को काफी अधिक प्रभावकारी पाया ',
#  'मंत्रियों की श्रेणियाँ',
#  'उनके अन्य क्षेत्र है रंगत व ग्रेट निकोबार ',
#  'कभी-कभी रकत का थक़्का , रक़्त के बहाव को पूरी तरह रोक देता है , जिसका भंयकर परिणाम होता है-हृदय आघात अर्थात हार्ट अटैक ',
#  'ड्रग्स के सेवन के बहुत -से लक्षण उम्र में बड़ा होने के आम लक्षणों जैसे ही होते हैं ',
#  'ऊटपटांग पूजा-पा और आध्यात्मिक कवायदों , सड़ेक किनारे खेल दिखाते सपेरों और निर्वाण की आकांक्षा में नंगे घूमते साधुओं का तो कहना ही क्या ',
#  'इसलिए यह स्वभाविक ही था कि वे साधारण जन की भाषा का इस्तेमाल करते ',
#  'ब्रितानी नीति ने साधनों को किसानों और कारीगरों से छीनकर सौदागरों , महाजनों और ब्रितानी पूंजीपतियों के हाथों में पहुंचाने में मदद की ',
#  'अगर आप चाहते हैं कि कोई कॉमिक प्रसिद्ध हो, तो लाइब्रेरी वालों को हीरो बनाइये। सही रहेगा।',
#  'कत्थक नृत्य का प्रारम्भ ६-७वीं शताब्दी में उत्तर भारत में हुआ था।',
#  'उनके नेतृत्व वाल ग बंधन आकार में बड़ जरूर है , लेकिन अपेक्षाकृत स्थिर है ',
#  'ड़ीपीसी अपने पहले चरण के संयंत्र में बतौर ईंधन नाथा प्रयोग करती है ',
#  'थोड़ी अवधि के बाद मुर्गे बदलकर यह दोष दूर किया जा सकता है ',
#  'मैं रहूं या न रंअं , खालिस्तान का दर्शन जारी रहेगा ',
#  'सारे विश्व को ले कर',
#  'मैं डेटा दिखाने के लिए नहीं जा रहा हूँ',
#  'यह आपकी शिकायत की गहराई पर निर्भर करता है',
#  'उसने अपनी सहायक भारतीय कंपनी के शेयरधारकों से अपने शेयर खरीदने की पेशकश की , ताकि वह शेयर बाजार की सूची से बाहर हो जाए ',
#  'लेकिन उस पर पुरुषों का वर्चस्व उसका कमजोर पक्ष था ',
#  'इस्लाम में हिन्दू धर्म के समान समय के परिपत्र होने की अवधारणा नहीं है।',
#  'यहां पर अन्य स्थानीय लोगों की भी सीप तथा काष्ठ की अनेक दुकानें हैं जहां पर दुर्लभ कलाकृतियां मिलती हैं जिन्हें स्मृति चिन्ह के रूप में लोग खरीदते हैं ',
#  'धार्मिक स्थितियाँ- बारहवीं शताब्दी के पूर्वार्ध में कर्नाटक में जैन , वैष्णव , शैव और बौद्ध धर्मो का प्रचलन',
#  'अब्राहम-पथ के कुछ भागों पर',
#  'तैंतीस वर्षों के रचनात्मक जीवन में वे साहित्य की ऐसी विरासत सौप गए जो गुणों की दृष्टि से अमूल्य है और आकार की दृष्टि से असीमित।',
#  'उसी ने उसका पालन-पोषण किया।',
#  'लेकिन बाद में अंग्रेजों का पगडा भारी पडा और दोनो फौजो को पिछे हटना पडा।',
#  'विशेषकर नौकरी की संभावना उन लोगों के लिए क्षीण हो गयी जो बी.ए . का प्रमाण-प्रमाण पत्र पाने से पहले विश्वविद्यालय की पढ़ाई खत्म करने के लिए विवश थे ',
#  'इच्छित कर्म करने के लिये इनमें से एक या कई देवताओं को कर्मकाण्ड और पूजा द्वारा प्रसन्न करना ज़रूरी है।',
#  'यह सच है कि किसी भी ड़ाक व्यवस्था में सैसड़ी निहित होती है लेकिन निचले स्तर के कर्मचारियों को राहत पहुंचाने के लिए कई उपाय किए जा सकते हैं ',
#  'महादेवी हज़ारी प्रसाद द्विवेदी आदि के साथ',
#  'क्यों कि उसने एक समय के बारे में बताया था',
#  'श्री रामचरित मानस-लंका काण्ड',
#  'धीरे धीरे यह भावना लुप्त हो गयी।',
#  'यह राजस्थान के निर्माण की दिशा में पहला कदम था।',
#  'बादामी के पूर्ववर्ती चालुक़्यों की एक सगोत्री शाखा के वंगी के पूर्वी चालुकयों ने , फिर भी , बालुकाश्म में बने संरचनात्मक मंदिरों की एक श्रृंखला छोड़ी है जो अपनी शैली में उनके दक्षिण में तौडैंमडलम की पल्लव शैली के अधिक समान है ',
#  'ये जानवर दूध बहुत अधिक मात्रा में देते हैं ',
#  'यह स्थान विश्वव्यापी मतदान से हुआ था जहाँ इसे दस करोड़ मत मिले थे।',
#  'पर हमें यह भी याद रखना चाहिए कि',
#  'वायु प्रदुषण के स्त्रोत विभिन्न स्थान गतिविधि या घटक सूचित करते हैं जो',
#  'मुहम्म्द साहब ने अपने मक्का से मदीना पहुंचने के बाद वहाँ के यहूदियों के साथ एक संधि करी जिसमें यहूदियों की धार्मिक और सांस्कृतिक स्वायत्तता को स्वींकारा गया।',
#  'एक बार जब वो विश्वास बन गया',
#  'जो हमारे अंदर छुपी हैं',
#  'लगभग हर आधे घंटे में इस जलड़मरूमध्य से कच्चे तेल का एक टैंकर गुजरता है इसलिए ढुलई के खर्च में भारी बढेतरी हो जाएगी ',
#  'संघीय क्षेत्रॉ को भी राज्य सभा मे प्रतिनिधित्व मिलता है जिससे इसका स्वरूप गैर संघीय हो जाता है',
#  'एक बार किसी ने गुरुदेव की सेवा में घृणा और लापरवाही दिखाई तथा घृणा से नाक भौंहें सिकोड़ीं।',
#  'कीमतों में वृद्धि होती रही जिससे बहुलता के समय में भी उपभोक़्ता को कोई लाभ प्राप्त नहीं हुआ ',
#  'मगर ये आपके साधन थे ,किसी ओरके नहीं ',
#  'आपने इन्हें देखा होगा',
#  'औद्योगीकरण के अभाव के कारण परेशानी ज्होल रहे ओड़ीसा में अतीत में इस तरह की रणनीति कारगर रही है ',
#  'दैनिक यशभारत',
#  'जिनका पालन दूसरे लोग करते हैं ।',
#  'न सिर्फ़ मानवो पर ही',
#  'इसमें तुमसे पूर्व गुज़रे हुए लोगों के हालात हैं।',
#  'विमान की बाहरी दीवार और उसके अगले मंडप की दीवार के विस्तार के ऊपर स्थित प्रस्तार में कर्णकूटों और शालाओं का एक हार है जो नीचे के उभार वाले खंडों के अनुरूपक हैं ',
#  'और यह कि जीवंत चित्रों के ज़रिये इन्हें बेहतर दिखाया जा सकता है।',
#  'यहाँ से मीरजापुर पटना भागलपुर होते हुए पाकुर पहुँचती है।',
#  'शोर प्रदूषण का एक अधिक गंभीर प्रभाव है आंतरिक कान में रोम कोशिकाओं को होने वाली चिरकालिक क्षति ',
#  'जिसने बुनियादी तौर पर मेरी समझ को बढ़ा दिया',
#  'लोगों का कहना है कि उसे ऐसे किसी देश में रहने की अनुमति नहीं है जिसमें वह घास नहीं उगती जिसे वह अनामिका में पहनता है या जहां काले बालों वाले मृग नहीं चरते ',
#  'और हमे इन दिमाग के विभिन्न प्रकार के साथ काम करना है',
#  'सरकार ने ऐसा काबुल के बाहर और पतून भल इलकों में अपनी पकड़े बनाने के इरादे से किया ',
#  'यह भाप इंजन की अपेक्षा अधिक सस्ता और सक्षम है और इसने भाप इंजन को समाप्त कर दिया है ',
#  'इन संदेशों का शुभारम्भ आदम से हुआ था।',
#  'थोड़ी सी उपेक्षा से भी बहुमूल्य जानवर खो दिये जाने की आशंका रहती है ',
#  'मद्रास में कंपनी ने राजदरबारों के समय की तरह कारीगरों को अपने कारखानों में नौकरी के लिये आकर्षित करने का प्रयत्न किया ',
#  'जो काम समाज की भलाई के प्रतिकूल होते थे , उन्हें देवी-देवताओं को अप्रसन्न करने वाला माना जाता था और यह समझा जाता था कि प्लेग , भूकंप आदि आपदाएं दैवी प्रकोप की प्रतीक हैं ',
#  'वहां उनके पूर्व परिचित तो मिले ही लेकिन कुछ के साथ नई मित्रता कायम भी हुई - उनमें से उल्लेखनीय दो महिलाओं के नाम हैं - हेलन केलर और जेन ऐडम्स ',
#  'प्राचीन काल में राजस्थान',
#  'जिसका वर्णन हस्तक्षेप के अध्ययन के द्वारा किया गया था',
#  'हमें आशा दे कर।',
#  'इस अंतिम वर्ग के मार्गदर्शक थे , ए.सी.एन . नांबियार , जिन्होंने इंडियन नेशनल कांग्रेस की ओर से बर्लिन में इंडिया इंफार्मेशन ब्यूरो की स्थापना की थी ',
#  'संयुक़्त प्रांत में मंत्रियों संबंधी संकट उन्होंने दक्षतापूर्वक निपटाया था ',
#  'दैनिक जागरण की सफलता का कारण इस पत्र का जनोन्मुखी होना है।',
#  'सरकार अभी यह तय नहीं कर पाई है कि पुराने शहर में रहने वाले कितने परिवार बाहर बसेंगे ',
#  'प्रणिता की मां एक वेश्या थी',
#  'उसने ईर्ष्यावश राजा के कान भरे और सुनीती को पुत्र सहित राज़्य के बाहर निकलवा दिया ',
#  'फिब्बि मंच अष्टांक सॉफ़्टवेयर के हिन्दी प्रचार प्रसार अभियान का एक अंग है ।',
#  'जेसा कई वक्ताओं ने पिछले कुछ दिनों के दौरान कहा है',
#  'आयात रूक गया और मांग बढ़ गयी ',
#  'इसे साइकिल का वाल्व ट्यूब कहते हैं।',
#  'हम सिर्फ यह जानते हैं कि सैंकड़ों लोगों ने',
#  'प्रेम जताने की क्रिया अक्सर मैथुन से पहले निभाई जाती है।',
#  'यह ईमेल या इंस्टैंट मैसेजिंग जैसे साधनों में प्रयुक्त पुश तकनलाजी से ठीक उलट युक्ति है।',
#  'शूर्पणखा ने जाकर अपने भाई रावण से शिकायत की।',
#  'शिक्षा मुत दी जाती है और कई छात्रों को रहने तथा खाने की सुविधा भी मुत है ',
#  'कवि उसके साथ एक अनूठा संबंध महसूस करता है और इस बारे में अपनी कविता में विस्तार से बताता चलता है ',
#  'बस यही। धन्यवाद्।',
#  'ग्रन्थसूची',
#  'वे प्रकृति की सभी मुद्राओं से प्रेम करते रहे , यहां तक कि प्रचंड गर्मी , धूल भरी आंधी ने भी उनकी कविताओं और गीतों में अमरत्व प्राप्त किया ',
#  'चारों ओर चमकते दीपक अत्यंत सुंदर दिखाई देते हैं।',
#  'केवल प्रोपेगंडा और आंदोलन से हम बहुत दूर नहीं जा सकते ',
#  'इस प्रकार , धागे और थान के संबंध में हमारी आवश्यकता का नाममात्र हिस्सा ही आयात किया',
#  'किंतु अब , राजनैतिक उतार-चढाव ने , सीधे उनकी अधिकारिक प्रतिष्ठा तथा विशेषधिकारों को चोट पहुंचाई और अप्रत्यक्ष रूप से उनकी सामाजिक स्थिति और प्रभाव को समाप्त कर दिया ',
#  'तो विभिन्न अन्य क्षेत्रों में विशाल अवसर हैं।',
#  'इस अवस्था में घोड़े को मुलायम मुंह वाला कहा जाता है ',
#  'यह भी सत्य है कि शताब्दी के बदलने के समय तक , सूत और जूट , दो ही बड़े पैमाने के आधुनिक उद्योग थे लेकिन कोयला-खदान , लौह-प्रगालन और रेलवे कारखानों की सीमित शुरूआत भी हो चुकी थी ',
#  'उनकी संपत्ति भी जब्त कर ली गयी ',
#  'मैंने अपना बाइक हेलमेट लिया',
#  'इसके तुरंत बाद ही , शिकागो विश्वविद्यालय ने उन्हें अपने यहां व्याख्यान के लिए आमंत्रित किया ',
#  'और मेरी कलाकृति के बारे में बताना चाहूँगा।',
#  'संभवतया किसान वर्ग ब्रितानी उपनिवेशवाद का मुख्य शिकार था ',
#  'जल्द ही एक ऐसी भी घड़ी आई जब उसका आना बंद हो गया और घाट को उसकी सहेलियों की बात से पता चला कि छोटी-सी कुसुम का विवाह हो चुका है और वह अपने पति के घर दूसरे गांव चली गई है ',
#  'यद्यपि इसे चालुक़्यों और पल्लवां दोनां के अल्प विमानों , के प्रथम , द्वितीय या तृतीय तलों की संरचनात्मक पक्षों में दुहराया नहीं गया , फिर भी बड़े जाति और मुख़्य विमानों के अपरिवर्तनीय घटक के रूप में निद आठवीं शताब्दी से आगे दिखाई पड़ता है ',
#  'उत्तर में पहाड़ और दक्षिण में विशाल झील इसकी सुंदरता में चार चांद लगाते हैं।',
#  'और ये फिर से सिद्ध करता है कि',
#  'तो जो हम यहाँ देख रहे हैं',
#  'अकबर के शासन काल से पहले न्यायिक प्रक्रिया पर भी पारंपरिक मुस्लिम विधि लागू की जाती थी ',
#  'उनकी सातवीं पीढी ब भी अपने अधिकारों के लिए संघर्षरत है।',
#  'एरिज़ोना',
#  'हमारे जीवन का एक दुखदायी परिणाम यह है कि हम दुनिया की खाज भाषा के माध्यम से करते-करते भाषा को ही दुनिया मान बैठते हैं ',
#  'लेकिन कंपनी ने अपना ध्यान युद्ध की आवश्यकताओं की पूर्ति पर लगाया ',
#  'सदन से बाहर भी सदस्यों से आशा की जाती है कि वे अपने पद की गारिमा के अनुकूल आचरण का स्तर बनाये रखेंगे ',
#  'मै भाषा मे नही सोचती',
#  'लेकिन अर्जुन ने उसके अनुरोध को यह कहकर ठुकरा दिया कि उसने ब्रह्मचर्य-पालन की शपथ ले रखी है और किसी नार्रीदेह का संस्पर्श तक नहीं कर सकता ',
#  'मेरी सक्रिय भागीदारी के साथ, दुनिया के बेहतरीन सॉफ्टवेर लेखक',
#  'उन देशों के लिए, जिनके पास पीने का साफ़ पानी नहीं है',
#  'सामाजिक क्रांतिकारी',
#  'मसलन , नेट बैंकिंग ',
#  'पर यह इसका बड़ हिस्सा है ',
#  'जो हम सीख रहे हैं, उसका एक भाग यह भी है',
#  'इस्लाम एकेश्वरवाद को मानता है।',
#  'अंपायर और स्कोरर',
#  'एक मनोवैज्ञानी के तौर पर, मैं चिंतित',
#  'वे खाने की मेज पर भी खामोश और उदास बैठे रहते जिससे कि इस परेशान मेहमान को और भी उलझन होती ',
#  'खैर , चौटाल परिवार के लिए यह कोई नई बात नहीं है.राजनीति तो हमेशा से उनके लिए पारिवारिक मामल ही रही है.है न ',
#  'तो मुझे ये बार-बार आमदनी वाली बात ही बचपन में ही सीखने को मिल गयी ।',
#  'कुछ कीट तो इस क्रिया को बहुत ही साधारण रूप में लेते हुए मित्र के यहां जा धमकते हैं और इस बात का रत्तीभर मलाल नहीं करते कि उनके क्रुद्ध मित्र ने उन्हें बेइज़्जत करके बाहर निकाल दिया है ',
#  'सुबा अरसे से संदेह के दायरे में हैं ',
#  'इसके बाद नरेंद्र ने उनके ठहरने के लिए एक सुरक्षित स्थान का प्रबंध मौंहदिया गांव में किया जो बलसोर से विशेष दूर नहीं है और यूनीवर्सल एम्पोरियम नामक व्यापारिक केंद्र संप्रेषण का माघ्यम बनाने के लिए खोला गया ',
#  'कश्मीर हमारी सबसे बड़ी राजनैतिक समस्या बनी ही है और तेजी से गंभीर रूप ऐतयार करती जा रही है.इसका अंतरराष्ट्रीयकरण भी खूब हा है , क्योंकि हमें एक ऐसी सरकार मिली ही है जो , लगता है , इसके राजनैतिक समाधान की वास्तविक कोशिश करना ही नहीं चाहती ',
#  'संसद से निवेदन किए जाने पर भी वह राज़्य सूची के किसी विषय पर विधान बना सकती है ',
#  'डिक्शनरी पर आश्रित था',
#  'स्थानीय समस्याओं का निदान कर रहे हों',
#  'है कि लोगों को कि वे वैश्वीकरण चिंता बढ़ा रहा है।',
#  'इस बार-पुणे-संधि-की तरफ जब ब्रिटिश सरकार का ध्यान दिलाया गया तो उसके पास इसे अनुमोदनार्थ पार्लियामेंट को भेजने के अलावा कोई चारा ही नहीं था ',
#  'यदि आप बच्चों और किशोरों से यह पूछें कि वे ड्रग्स का प्रयोग क्यों करते हैं , तो वे कहेंगे ः',
#  'वह इसे हमेशा अपने साठ रखती है',
#  'मैं अब विश्व बैंक के साथ परिसंपत्ति वसूली पर, एक पहल पर काम कर रही हूँ',
#  'कुछ इसे आर्यों की पूर्ववर्ती शाखा कहते हैं तो कुछ इसे द्रविड़ ।',
#  'एक दूसरा रास्ता है',
#  'राय के कुछ सहयोगी भी जो देश के विभिन्न भागों के थे वहां उनसे मिलने के लिए तथा अपने बीच स्वागत करने के लिए एकत्रित हुए थे ',
#  'ऐसे वक़्तव्य पर वाद विवाद नहीं होता परंतु ऐसे प्रत्येक सदस्य को जिसका नाम कार्यसूची में दर्ज हो , स्पष्टीकरण के लिए एक प्रश्न पूछने की अनुमति दी जाती है ',
#  'अन्य',
#  'कृतियाँ',
#  'अरब बनाम इस्राइली, मज़दूर बनाम प्रबंधन',
#  'गांधीनगर में ऐसी अनियमितताओं की सूची लंबी है ',
#  '१९६२ में चीन के साथ तथा १९४७ १९६५ १९७१ एवम् १९९९ में पाकिस्तान के साथ लड़ाइयाँ हो चुकी हैं।',
#  'यह शब्द इसके सीरियाई समानांतर कुरियना का अर्थ लेता है जिसका अर्थ होता है ग्रंथों को पढ़ना ।',
#  'इन्हें भी देखें',
#  'आंतरिक कक्ष एक अष्टकोण है जिसके प्रत्येक फलक में प्रवेश-द्वार है हांलाकि केवल दक्षिण बाग की ओर का प्रवेशद्वार ही प्रयोग होता है।',
#  'मार्च २००४ में यहां मुंबई ग्रैंड प्रिक्स एफ़ १ पावरबोट रेस की विश्व प्रतियोगिता का भाग आयोजित हुआ था।',
#  'भारत मे अंतरजाल',
#  'कवि ने स्वयं बताया कि उसके लिए यह नाव और कुछ नहीं , जीवन का प्रतीक है.यह हमारी उपलब्धियों का स्वर्णिम फसल बटोर लेती है और हमें पीछे छोडऋकर इऋर काल के प्रवाहों पर बहती चली जाती है ',
#  'उन्होंने सरकार से उनके पक्ष में बाजार में हस्तक्षेप करने और उनसे कुछ अनिवार्य खरीद करने का अनुरोध किया ',
#  'चलिए , मान लिया लेकिन ऐसे आतंकवादी गुट से क्यों बात की जा रही है जिसे पाकिस्तान ने घाटी में अपना मकसद साधने के लिए लगाया है ',
#  'विदेश लिंक्स',
#  'तो इस महिला में आती है और वह ऑपरेटिंग कमरे में ले जाई गयी',
#  'धर्मों का कला के प्रति काफ़ी साफ़ नज़रिया है',
#  'दस दिन दूर थी ये साबित करने से कि जो उत्पाद उन्होंने बनाया है, वो',
#  'केसे करके , अचानक ये बातो पे वे गौर करने लगे',
#  'इ-मेल पते से यहाँ संपर्क कर सकते हैः',
#  'उनके गलफड़ों में एल्यूमीनियम के यौगिक जमा हो जाने से उन्हें सांस लेने में भी तकलीफ होती है ',
#  'परब्रह्म असीम अनन्त और रूप-शरीर विहीन है।',
#  'उनकी वर्षगांठ उस छोटे-से पहाड़ी स्थान पर जितनी सादगी और सौम्यता से मनाई गई , वह शायद ही कलिम्पोंग जैसी बड़ी जगह में संभव हो पाती , कलकत्ता जैसे शहर में तो और भी नहीं ',
#  'शिक्षक के कॉण्ट्रैक्ट में',
#  'इसलिए , कोई भी राज्य संघ से अलग नहीं हो सकता और न ही अपनी मर्जी से संविधान की प्रथम अनुसूची में निर्धारित अपने राज्य क्षेत्र में परिवर्तन कर सकता है ',
#  'सच में',
#  'भारत का संविधान भारत को एक सार्वभौमिक समाजवादी धर्मनिरपेक्ष लोकतान्त्रिक गणराज्य की उपाधि देता है।',
#  'मैं इसी विषय में काम करती हूँ',
#  'हमने उन सब को फिर से संगठित किया, ठीक किया।',
#  'संपूर्ण कार्यकलापों पर विचार करने की उत्सुकता के कारण , संसद की टिप्पणियां , और आलोचना सामान्य और औपचारिक रूप ले लेती हैं और एक ही बात को दोहराने की प्रवृत्ति बन जाती है ',
#  'अंधकार पर प्रकाश की विजय का यह पर्व समाज में उल्लास भाई-चारे व प्रेम का संदेश फैलाता है।',
#  'परिप्रेक्ष्य था, यहाँ इस गरीब प्रोफेसर है',
#  'कोई भी जो कभी कभी भूल जाता है या जो कभी कभी अपने जानने वालों के नाम या शापिंग लिस्ट पर लिखी वस्तओं के नाम याद नहीं रख सकता है , यह जरूरी नहीं है कि वह मानसिक रोगी हो ',
#  'बल्लेबाजों की भूमिका रन बनने के साथ और ओवर पूरे होने के साथ बदलती रहती है।',
#  'ये परम बुद्धिमान कहे जाते हैं।',
#  'वह मुकदमों का निर्णय तभी कर सकता था जबकि प्रतिवादी आरोप को स्वीकार कर ले ',
#  'क्योकि यहाँ बहुत सा औटिस्म जेनेटिक्स है',
#  'प्रमुख टाइपैड',
#  'क्रूस को मरोडने में',
#  'और दुनिया में, हर २० मिनट में, एक नये व्यक्ति',
#  'आधिकारिक सूत्रों से हुए विचार-विमर्श के निष्फल सिद्ध होने पर सुभाष चन्द्र ने भारत संबंधी प्रचार के लिए प्रेस विज्ञप्तियां जारी करने , व्याख़्यान देने तथा लिखने-पढ़ने वाले लोगों से मेलजोल बढ़ाने की ओर ज़्यादा ध्यान देना शुरू कर दिया ',
#  'उन्होंने उन्हीं लगों को अपमानित किया या पार्टी से निकाल जिन्होंने उनकी मदद की थी और उन्हें आगे बढया था ',
#  'सदन की विशेष शक्तियॉ मे आता हो',
#  'प्राचीन समय में यह एक',
#  'एक ही महीने में केंद्र पहले स्वायत्तता , फिर ह्र्रियत से वार्ता और अब युद्धविराम की घोषणा से रू-ब-रू हा है ',
#  'संस्कृत हिन्द-यूरोपीय भाषा-परिवार की हिन्द-ईरानी शाखा की हिन्द-आर्य उपशाखा में शामिल है।',
#  'बहुत अलग और विशिष्ट होते हैं, और यह कि मैने वाक्यांश को बहुत अच्छी तरह से सीखा था',
#  'मां अपने बढ़ते हुए सदा-भूखे बच्चों के लिए ही अधिकाधिक मांस निगलती है ',
#  'तो हम कई जीवन बचा सकते हैं',
#  'लेकिन का़नून भी बदलें। वैश्विक सन्धियों को बदलें।',
#  'सब्जियों , कागज बेकार भोजन , प्लास्टिक तथा ऐसी अन्य वस्तुओं को खुले नालों में नहीं फेंकना चाहिए , बल्कि उन्हें कागज के थैलों में रखकर स्थानीय निकायों द्वारा कूडऋआ फेंकने के लिए गलियों में रखे गये कूडऋआदानों में फेंकना चाहिए ',
#  'बतखों पर जब पंख आ जाते हैं तो वे तालाबों , झीलों के आसपास रहने को तैयार हो जाती हैं.वहां पर घास , घोंघे तथा अन्य कीट उनका मुख़्य भोजन होते हैं ',
#  'जरा सोचिये, तब भी जब बाहर बादल हैं',
#  'ये गवाही दे सकते हैं कि पाकिस्तानी लोग बहुत मेहनती होते हैं।',
#  'मोनरोविया जैसे युद्ध-ग्रस्त इलाकों में',
#  'चाहे कोई भी प्रोग्राम हो ',
#  'पालतू कुत्तों की पूछें पिल्ला पैदा होने के तुरंत बाद काट दी जाती हैं परंतु इन्हीं दुमकटे कुत्तों की संतानें पूंछ के साथ ही पैदा होती रहती हैं ',
#  "इस शताब्दी के प्रारंभिक वर्षों में कलकत्ता ' महलों और उद्यानों का शहर ' जाना जाता था ",
#  'भूमि से लोग को विशेष मोह है.इसे बेचना तथा चुराना पाप समझा जाता है ',
#  'यथा-ऋग्वेद की २१ शाखा यजुर्वेद की १०१ शाखा सामवेद की १००० शाखा और अथर्ववेद की ९ शाखा- इस प्रकार कुल ११३१ शाखाएँ हैं।',
#  'वेदव्यास की महानता ही है जो कि ११ उपनिषदों के ज्ञान को एक पुस्तक में बाँध सके और मानवता को एक आसान युक्ति से परमात्म ज्ञान का दर्शन करा सके।',
#  'आप को उन्हें सर्च इंजिन से हटाना होगा',
#  'अंततः वह संकट टल गया , मगर तब तक आरएसएस के साथ भाजपा के संबंध भत खराब हो चुके थे ',
#  'दूसरो की नकल उतारने के कारण है।',
#  'हर नवम्बर में',
#  'और ये तो वैज्ञानिक तौर पर भी साबित हो चुका है',
#  'स्कैरब का लोकप्रिय नाम गुबरैला है क़्योंकि बकरी और गाय के गोबर की गेंद बनाकर यह उसको लुढ़काता है ',
#  'महत्वपूर्ण बात यह है कि आप क्या करते हैं',
#  'प्रौढ़ता की सीमाओं का प्रतिकार केवल सामाजिक परंपराओं में परिवर्तन द्वारा किया जा सकता है जिससे वृद्धों की दशा को बेहतर बनाने के लिए कुछ किया जा सके ',
#  'इसमें आश्चर्य की कोई बात नहीं होनी चाहिए कि जब यह प्रकाशित हुआ तो उसके लेखक को उसी प्रसिद्ध दिग्गज रचनाकार का एक पत्र मिला जिसमें उसे इस उपलब्धि के लिए बधाई दी गई थी ',
#  'उन पहले लोगों में से एक है जिसने इसके बारे मे ट्वीटर पर मज़ाक किया।',
#  'चतुराई और साहस के जोशीले',
#  'मेरा व्यवसाय, संगीत का व्यवसाय इसे इस तरह नहीं देखता है',
#  'अन्य कवियों में भारतेन्दु हरिश्चन्द्र सुमित्रानन्दन पन्त और श्रीधर पाठक आदि ने भी यत्र-तत्र गंगा का वर्णन किया है।',
#  'उन्नयन कदमः महिला चाहे तो अपने पार्टनर के खिंचाव को कम करने के लिये सीढ़ी या फिर स्टूल पर चढ़ सकती है',
#  'देवर भाभी के संबंधों को लेकर भी गीत परंपरित है ',
#  'और दस-साल का बच्चा हर आठ स्वरों पर',
#  'इस ग्रन्थ से यह भी प्रमाण मिलता है कि सूर के गुरु श्री बल्लभाचार्य थे।',
#  'पहला दूसरे को कुछ दही दे दे , और दूसरा पहले को कुछ चावल दे दे ',
#  'मुर्गीपालन पर होनेवाले कुल खर्चे का आधा तो इनके भोजन पर ही होता है ',
#  'यह सही है कि न्यायाधीशों को अभिलेख पर उपलब्ध सामग्री के आधार पर ही अपने निर्णय देने होते हैं और कोई व्यक्ति यह आशा नहीं कर सकता और न करनी चाहिए कि किसी व्यक्ति के विरुद्ध लगाए गए आरोप को सिद्ध करने के लिए विश्वसनीय साक्ष्य न हो तो भी न्यायालय उसे दोषी ठहराएगा ',
#  'इस नस्ल की भेड़ों से प्राप्त ऊन से सेना के लिए हौजरी और ऊनी कपड़ा तैयार किया जाता है ',
#  'हर जगह सन्नाटा छा गया , किसी को कुछ सूज्ह नहीं रहा था ',
#  'विजेताओं की संया भी खासकर दक्षिणी राज्यों में , जहां लॅटरी का सबसे ज्यादा कारोबार है , नीचे आ गई है ',
#  'और वह जो इशारे करता है, उन्हें पहचानता है',
#  'लाहौर गेट से चट्टा चौक तक आने वाली सड़क से लगे खुले मैदान के पूर्वी ओर नक्कारखाना बना है।',
#  'और कैसे इस विषय से निपटें',
#  'स्वचलित मत अभिलेखक प्रणाली के अंतर्गत , प्रत्येक सदस्य उदसे आवंटित स्थान से इस प्रयोजन के लिए लगाए गए अपेक्षित बटन को दबाकर अपना मत देता है ',
#  'जो कि जाहिर है. यह बहुत अच्छा नाम है',
#  'परंतु यह फूलों पराग के सिर गिनने से कहीं ज्यादा रूचिकारक है।',
#  'यह कहने का उद्देश्य कि आत्मा स्वर्ग में जाती है यह होता है कि आत्मा को पुण्य कर्म की ओर प्रवृत्त किया जाए ताकि उसमें यथासंभव अधिकाधिक पुण्य कर्म करने की लालसा उत्पन्न हो ',
#  'इसका प्रारम्भ सीमित था और विकास भी मंद गति से था ',
#  'इसके पलसस्वरूप अधिक ग़्लूकोज कोशिकाओं द्वारा इस्तेमाल होने या संग्रहित होने की बजाय रक़्त में ही रहता है तथा शरीर को उतनी उर्जा नहीं मिल पाती जितनी उसे मिलनी चाहिए ',
#  'एक अच्छी तरह से संतुलित टीम में आमतौर पर पाँच या छह विशेषज्ञ बल्लेबाज और चार या पाँच विशेषज्ञ गेंदबाज होते हैं।',
#  'पूरी दुनिया में कहीं भी ',
#  'गैस और बिजली बिलों के लिये बजट करना महत्वपूर्ण है ',
#  'किसी गरम और उमसभरी रात में आसन्न वर्षा से पहले यह झुंडों में उड़ान भरता है ',
#  'नई खोज कठिन है',
#  'यह और इस के साथ जुड़े हुए गाईड़ निर्देश नोटस हमारी आम पूछताछ के नंबर पर उपलब्ध हैंः ',
#  'श्रीमद् भगवद् गीता यथारूप-प्रभुपाद',
#  'इन्हें भी देखें',
#  'इस आयोग ने नेहरू रिपोर्ट पेश की।',
#  'संक्षिप्त सामान्य सेना न्यायालय में कम से कम तीन अधिकारी होते हैं ',
#  'कुल निर्यात वऋ-ऊण्श्छ्ष्-यापार के प्रतिशत रूप में जूट सामान के निर्यात में निरंतर गिरावट रही ',
#  'गंगा के पराभव का अर्थ होगा हमारी समूची सभ्यता का अन्त।',
#  'उसने अकबरनामा की भी रचना की थी।',
#  'फिर मेरी तरफ देखा और ऐसे इशारा किया',
#  'उसका नाम है नलिनी- एक ऐसा नाम जो रवीन्द्रनाथ के लिए सदैव प्रिय बना रहा ',
#  'इनके अतिरिक़्त , कुछ और भी विशिष्ट कारण थे जो अलग-अलग उत्पादों की मांग को प्रभावित करते थे ',
#  'नागपुर में सुषमा स्वराज का यह कथन मूल समस्या को छूता है कि पार्टी लगों को जाकर कायल करे , इससे पहले सरकार को अपनी आर्थिक नीति के औचित्य के बारे में पार्टी को कायल करना चाहिए ',
#  'और फ़िर उन्होनें कहा कि मैं आधे अखबार बेचने के लिये किसी को नौकरी पर रखूँ',
#  'यहां यह पूछना कोई गलत नहीं होगा कि क्या चार महीनों में कोई प्रगति ही है ',
#  'वे सफल नहीं हुए और इसी के साथ उनका कांग्रेस से संपर्क समाप्त हो गया ',
#  'यहां तक कि पिछले साल जनवरी में जब वाजपेयी ने एक चुनावी सभा को संबोधित किया तो वे मंच पर मौजूद नहीं थे जबकि अनंत कुमार वहां छाए रहे ',
#  'ऐसा लगता है कि करूंगुझी प्रवास के अंतिम वर्षो मे सन्मार्ग संगम की स्थापना के साथ रामलिंग को कदाचित लगने लगा था कि उन्होनें अपने आपको जीवन के महान लक्ष्य के लिए तैयार कर लिया है ',
#  'पर्यटन',
#  'इनमें से कुछ ने जर्मन विदेश विभाग के सहयोग से भारत में बगावत फैलाने का प्रयास किया था और प्रथम विश्वयुद्ध के दिनों से ही राजनीतिक निष्कासन भुगत रहे थे ',
#  'सदस्यों द्वारा आपस में तर्क-वितर्क करने या किसी अन्य सदस्य के भाषण पर या मंत्री के वक्तव्य पर बराबर टिप्पणियां करते रहने की अध्यक्ष द्वारा निंदा की गई है ',
#  'ये चार भाग सम्मिलित रूप से श्रुति कहे जाते हैं जो हिन्दू धर्म के सर्वोच्च ग्रन्थ हैं ।',
#  'तुम मुझे पकड़ नहीं सकते।',
#  'वो जानें बचा सकते हैं',
#  'मादक द्रव्यों का सेवन, नशीले पदार्थ, सब कुछ',
#  'मैं तो बस अपने परिवार के साथ रहने आयी थी',
#  'ज़मीन लगभग खो दी थी',
#  'पानी में मलजल प्रदूषण जब से हमने अपनी नदियों तथा अन्य जल स्रातों में मलजल बहाना शुरू किया है तब से जल प्रदूषण एक बहुत बडऋऋ समस्या बन गयी है ',
#  'आगे बढ़ने का तय करके',
#  'देवी और देवता',
#  'लेकिन आम धारणा तो यह थी कि नाइजीरियाइ लोग साहित्य नहीं पढ़ते',
#  'कि आप किसी से प्यार कर सकते हैं',
#  'ब्रेबोर्न स्टेडियम शहर के सबसे पुराने क्रिकेट स्टेडियमों में से एक है',
#  'वह बड़ी दृढ़ता से उस खाद्य पदार्थ को चखने से मना कर देते थे जो उन्हें प्रिय थी और जो बड़े जतन से उससे बनाई गई थी , दूसरी ओर बड़ी अधीरता से और एक बच्चे की तरह जंगली जंबू बेरों को खाने के लिए जिद करते जो उनके पास लाए जाते ',
#  'इंक्लटन के लिए कच्छ की यात्रा भारतीय विपदा से रू-ब-रू होने जैसी है , जो नंदीश के चेहरे पर साफ-साफ दिखती है ',
#  'द्वितीय विश्वयुद्ध के दौरान आज़ाद हिन्द फौज ने जापानी सेना के सहयोग से भारत पर आक्रमण किया।',
#  'लम्बे किनारों पर एक भारी-भरकम पिश्ताक या मेहराबाकार छत वाले कक्ष द्वार हैं।',
#  'वह आचरणों का निरीक्षक , नगरपालिका का कार्यपालक और कुछ मामलों में दंड देने की सीमित शक्ति से संपन्न न्यायाधीश',
#  'उत्तर प्रदेश में स्थित इलाहाबाद उच्च न्यायालय एशिया का सबसे बड़ा उच्च न्यायालय है।',
#  'और बासित और अमजद पहला नाम हैं',
#  'लेकिन नीति निपुण अंग्रेजों ने भारतीय नेताओं को इस बात के लिए सहमत कर लिया कि निकोबार द्वीप में स्थित हवाऋ अड्डे का प्रयोग आगामी कुछ वर्षों तक आर ए एफ करती रहेगी ',
#  'लेकिन अनुवाद में इसे जिस प्रकार बताया गया है उससे यह मालूम होता है कि वह हिमवंत से एक योजन से अधिक ऊंचा नहीं है ',
#  'मेहराबी छत एवं दीवारों पर यहाँ की अन्य इमारतों जैसे ज्यामितीय नमूने बनाए गए हैं।',
#  'मुयमंत्री के लिए भी यह फायदेमंद हा क्योंकि उनका निर्वाचन क्षेत्र गंजाम जिले में पड़ेता है ',
#  'और फ़िर वो बातचीत करते जाते है, करते जाते हैं, करते जाते हैं।',
#  'एक अधिकारी की तरक्की को दूसरे का हक मारना माना जाता है ',
#  'जैसा कि पिछले पैरा में संकेत किया जा चुका है , कुछ न्यायाधीश न्याय के हित में कभी कभी साक्षी से स्वयं कुछ प्रश्न करते हैं ',
#  'एक महान गतिशील साधन -',
#  'विश्लेषण - अणु',
#  'विशेषाधिकार देने का उद्देश्य यह है कि संसद के सदनों , उनकी समितियों तथा उनके सदस्यों की गरिमा एवं प्रतिष्ठा को तथा कार्य करने की उनकी आजादी को बनाए रखा जा सके और वे बिना किसी विघ्न या बाधा के काम कर सकें ',
#  'कि यह संस्कृति की भौतिकी है ',
#  'प्रदूषण हवा को दूषित करता है और पानी को जहरीला बनाता है ',
#  'स्वतंत्रता संग्राम में प्राण न्यौछावर करनेवालों के परिवार के सदस्यों को महापालिका में नौकरी मिलने लगी।',
#  'इसकी पिछली दीवार पर प्रक्षिप्त मंदिर वेदी के दोनों और दो और फलक हैं जिन पर गजलक्ष्मी और दुर्गा हैं ',
#  'जोश - १८',
#  'और कुछ एल्गोरिदम जो उन्हें खोजने के लिए क्रमादेशित हैं',
#  'लेकिन पोर्ट ब्लेयर में एक गैर सरकारी समिति है जिसमें सरकारी अधिकारियों के अतिरिक्त उपभोक्ता तथा व्यापारियों के प्रतिनिधि संयुक्त रूप से आवश्यक वस्तुओं के मूल्य निर्धारित करते हैं ',
#  'यहाँ हमें एक परिवार मिलता है जो करीब ३ डॉलर प्रतिदिन कमाता है।',
#  'कबीर के राम निर्गुण-सगुण के भेद से परे हैं।',
#  'इसलिए स्वाभाविक रूप से वह हर दृष्टि से पराजित था ',
#  'पहले से बहुत ज्यादा , अपने करियर के बारे में, आज कि दुनिया में अपनी स्थिति के बारे में',
#  'और बहुत उत्साहित हुई जो भी जी-८ के साथ हुआ, उसे देख कर -',
#  'उस व्यक्ति को सॉल्वैंट सूँगने से रोकने की कोशिश कीजिए - लेकिन बलप्रयोग मत कीजिए',
#  'जब तक नई निकली तरूण बर्र का घट को फोड़कर बाहर निकलने का समय आता है तब तक गोंद सूख चुका होता है ',
#  'गुजरात के खेतों में तो आनुवंशिक लड़ई लड़ी जा रही है ',
#  "हमारे 'द ९९' के साउदी सदस्य के साथ",
#  'आखिर में मैंने उनसे दो-एक दिन में आने का वादा किया ',
#  'ये तमाम विशेषताएं जहां हारमनी-संगीत के लिए अत्यंत महत्वपूर्ण और सौंदर्यवर्द्धक हैं , वहां भारतीय संगीत प्रतिभा के लिए बिल्कुल परायी हैं ',
#  'कमरे की खिड़कियों पर सूर्य की सीधी किरणें नहीं पड़नी चाहिएं ',
#  '१ सूरसागर - जो सूरदास की प्रसिद्ध रचना है।',
#  'सावरकर , तिलक और महात्मा गांधी के मुकदमों की तरह भगत सिंह अनके साथियों के मुकदमे भी भारत के मुक़्ति-संग्राम के इतिहास में अपना विशिष्ट स्थान रखते हैं ',
#  'वे तो सिर्फ अच्छे विचारों के बारे में सोचते हैं',
#  'ईश्वर एक नाम अनेक',
#  'और मैं उसे देखती रही',
#  'जब कभी भी हम',
#  'गूगल इण्डिक ट्राँसलिट्रेशन',
# ...
#  'कांग्रेस कई वर्षों से साम्राज़्यवादी युद्धों में , कहीं भी , ब्रिटेन द्वारा भारत के शोषण का विरोध करती आ रही थी ',
#  'जन्म और कौटुंबिक जीवन',
#  'बिक्री और उत्पादन के आंकड़ें की चाल सुस्त रही है और कृषि उत्पादन पिछले साल के मुकाबले कम होने की संभावना है ',
#  'कहा जा सकता है कि संसदीय प्रणाली में कार्यपालिका के उत्तरदायित्व की संकल्पना पर अधिक बल दिया जाता है जबकि राष्ट्रपतीय प्रणाली में स्पष्टतया कार्यपालिका के स्थायित्व को अधिक महत्व दिया जाता है ',
#  'इसलिये वो इस व्यस्त दुनिया मे खो नही जाते',
#  'यह पाबंदी जरूरी है , नहीं तो जमींदारियां दुबारा बन जायेंगी ',
#  'श्रीकृष्ण-काव्य स्वतंत्र प्रेम-प्रधान काव्य है।',
#  'उनकी मांग थी कि वे सालों से शासन चलाते आ रहे है।',
#  'शहर में लोक सभा की छः व महाराष्ट्र विधान सभा की चौंतीस सीटें हैं।',
#  'औरत-मर्द की बराबरी के लिये।',
#  'और अपने तरीके उस में ढालते हैं',
#  'ये है कि इस अंतर को कैसे कम करें',
#  'मैं हर जगह प्रकाशित किया. मैंने लिखा और सब कुछ मापा',
#  'देखिये, देवताओं को भी',
#  'तो भविष्य का हवाई जहाज कैसा हो सकता है ',
#  'जिस बोझ को संभालना पड़ता है -',
#  'इस संविधान सभा के लिए चुनाव का ब्यौरा तैयार करने के लिए जनता के प्रतिनिधियों की एक कमेटी बनायी जानी चाहिए ',
#  'कांग्रेस अभी किसी मुद्दे पर ओस रवैया नहीं अपना पाई',
#  "इसी के सदृश्य अपूर्ण ' अरगंडनल्लुर ' गुफा मंदिर में , जो मुखाग्र पर और पिछली पक्तिं में चार स्तंभों और दो भित्तिस्तभों से युक़्त है , पिछली दीवार पांच मंदिर कक्षों के चिन्ह हैं , जो काटे नहीं गए ",
#  '७० साल पहले एक इंसान ने',
#  'कि खिलौने के साथ बच्च सबसे अच्छा काम उसे तोड कर ही करता है।',
#  'उन्होंने सवालों की झड़ी लगा दी जिनका जवाब गांधी जी अपने स्वाभवगत धैर्य से देते रहे ',
#  'राष्ट्रवादी-अलगाववादी',
#  'पेंड़्रा से अमरकंटक को जाने वाली सड़ेक पर अचानक अवरोधक लगा दिए गए हैं , क्योंकि दोनों राज्यों के सड़ेक परिवहन विभागों ने माल के प्रवेश पर चुंगी वसूलना शुरू कर दिया है ',
#  'प्रौद्योगिकी के बारे में हाल ही में रूपकों में',
#  'इसके विपरीत देखा यह गया है कि उपयुक़्त आयु में बछड़ों को बधिया करवा देने से बैलों की सक्रियता उल्लेखनीय मात्रा में बढ़ जाती है और उनकी देखभाल में भी अधिक आसानी होती है ',
#  'अब यह भी हो सकता है कि हमें ऐसे स्थान मिलें जो बहुत, बहुत सघन हैं',
#  'उसने कभी झूठ नही बोला है',
#  'मैं आप को बता सकता हूँ कि वो बहुत ही भव्य है॰',
#  'और उनमें से एक मेरे पास अगली सुबह आया और बोला',
#  'रामानन्द जी गंगास्नान करने के लिये सीढ़ियाँ उतर रहे थे कि तभी उनका पैर कबीर के शरीर पर पड़ गया।',
#  'स्पष्टतया ये नाम उन संरचनाओं की योजना तथा शैली की और इंगित करते',
#  'अधिकांश पूराण विष्णु के नाम से हैं और कुछ ब्रह्मा या शिव के नाम से ',
#  'उसे किसी भी सतह तक जाकर',
#  'गोधूलि के समय ताज',
#  'जिला मजिस्ट्रेट , जो राज्य सरकार के नियंत्रण में होते हैं , समय समय पर उन स्थानीय सीमाओं को परिनिश्चित करते हैं जिनके भीतर कार्यपालक मजिस्ट्रेट अपनी शक्तियों का प्रयोग कर सकते हैं ',
#  'सात प्रतिशत से भी कम बच्चे',
#  'कुछ कीट ऐसे भी हैं जो पत्तियों , झाडियों , घास आदि में और खुले मैदान में भी समागम करते हैं ',
#  'सेल्युकस नेक्टर सिकन्दर के सबसे शक्तिशाली उत्तराधिकारियों में से एक था ।',
#  'धर्मशाला',
#  'बम फटने के बाद उन्होंने इन्कलाब-जिंदाबाद का नारा लगाना चालू कर दिया ।',
#  'तत्कालीन वायसराय लार्ड मेयो की हत्या के बाद प्रशासन का विकेन्द्रीकरण किया गया तथा एक नव सृजित पद चीफ-कमिश्नर के सीधे नीचे रखा गया ',
#  'काला घोड़ा कला उत्सव कला की एक प्रदर्शनी होती है जिसमें विभिन्न कला-क्षेत्रों जैसे संगीत नृत्य रंगमंच और चलचित्र आदि के क्षेत्र से कार्यों का प्रदर्शन होता है।',
#  'दुर्भाग्य से सरकारी स्कूल कार्य नहीं करते',
#  'अनडरएस्टीमेट करने लगा',
#  'आपके स्वास्थ्य को हानि पहुँचाने की संभावना रखने वाले तत्वों पर रोक लगाना या उनके सम्पर्क में आने पर पर्याप्त नियंत्रण रखना ',
#  'और मैने वापस जा कर उस का शिक्षक-संस्करण देखा।',
#  'साफ दूध की तुलना में बिना साफ किया दूध अधिक जल्दी खट्टा हो जाता है ',
#  'दीवारें चित्रांकित हैं और कृष्ण , क्षेत्रपाल , नरंसिह , नरसिंह , षष्ठ , गरूड , आदि उपदेवताओं के लिए उपमंदिर बने हुए हैं ',
#  'धन्यवाद',
#  'अकबर चाहता था कि उसके पूरे साम्राज्य में समान मुद्रा चले।',
#  'परंतु हमें कुछ विशेष मुद्दों के बारे में कुछ प्रतिवेदन प्राप्त हुए हैं और इन मुद्दों में , सहायता प्राप्त रोजगार कार्यक्रम , स्वैच्छिक कार्यकर्ता , आवास प्रतिपूर्ति , टिप , सामाजिक देखभाल प्रनाली का वित्तपोषण और उत्पादक श्रमिकों के लिए उचित अनुमान करार शामिल है ',
#  'इसमें कहा गया है कि न्यायाधीशों के काम का एक भाग यह भी है कि वे अपराधी और साक्षियों की मुद्रा , चालढाल और उनके स्वर तथा अभिव्यक्ति में होने वाले परिवर्तनों का अध्ययन करके उनके हृदय को टटोलें ',
#  'इससे दर्शनशास्र में एक नई लहर पैदा हूई जिसे इबनसीनावाद कहते हैं।',
#  'याहू भारत हिन्दी समाचार',
#  'पर ये अनुमति भी बहुत सारी शर्तों और हिदायतों के साथ दी गई',
#  'आमतौर पर दूसरा या तीसरा सबसे अच्छा पूर्वानुमान सही जवाब था।',
#  'चीन बेहतर था, सांस्कृतिक क्रांति के दौरान।',
#  'तीन के अंक के महत्व के बारे में, सारी संस्कृतियों मे, तो मुझे लगा कि मैं ठीक हूँ।',
#  'वे दोषहीन हैं',
#  'अगर आप पहले से १०० साल, या ८० साल के भी हैं -',
#  'धन्यवाद।',
#  'उससे ज्यादा गलत कुछ हो ही नहीं सकता है ।',
#  'टिड्डे टिड्डे हरी घास और छोटी छोटी वनसऋ-ऊण्श्छ्ष्-पति के बीच प्रसनऋ-ऊण्श्छ्ष्-न रहते हैं , वही उनके धर हैं ',
#  'अन्यथा , उपचार केवल राजनीतिक हो सकता है ',
#  'दीपावली दीपों का त्योहार है।',
#  'ः भगवान राम की एक प्रतिमा मस्जिद में स्थापित की गई ',
#  'वे नियमित तौर पर बायें हाथ से गेंद फेंकने का अभ्यास करते हैं।',
#  'संयुक्त राज्य अमेरिका',
#  'शाकाहार',
#  "टिप्पर और मैं गाड़ी में जा रहे थे, शोनी'स, कम आय वाले परिवारों के लिए भोजनालय श्रृंखला",
#  'उनमें राजनैतिक महत्वाकांक्षाएं न होना भी युद्ध के बाद उभरने वाले सत्ता समीकरण में मोर्चे की एकता के लिए लभकारी है ',
#  'कहानी और उपन्यास दोनो में युगान्तरकारी परिवर्तन पैदा किए।',
#  'पांचवें अध्याय में यह बताया जायेगा कि यह जानकारी डी.एन.ए . अणु में तीन अक्षरों से बने शब्दों में अथवा कंडोंनों में संग्रहित की जाती है ',
#  "वर्ष के पश्चात ' फुल्याच ' य ' डख्याङ ' के समय लामा मृतक के नाम वस्त तथा भोजन लेता है ",
#  'इस भाग में वर्षा का औसत ५० से.मी. से ९० से.मी. तक है।',
#  'और यहाँ ओईसीडी और लेटिन अमेरिका, पूर्वी यूरोप, पूर्वी एशिया',
#  'इस कारण इस दिन को हर साल राजस्थान दिवस के रूप में मनाया जाता है।',
#  'ज्यादा मज़बूत स्थिरता पैदा करने की ज़रूरत है',
#  'लेकिन इसके बावजूद दूसरे देश उन्हे उच्चकोटि का अम्पायर नहीं मानते ',
#  'भारतीय वास्तुकला में पश्चिमी प्रभाव से स्थान का सदुपयोंग आया , विशेषकर सीधी रेखाओं के प्रयोग तथा आधुनिक स्वास्थ्य विभाग को ध्यान में रखने के कारण ',
#  'सदन की विशेष शक्तियॉ मे आता हो',
#  'बच्चन जी हिन्दी के सर्वाधिक लोकप्रिय कवियों में अग्रणी हें।',
#  'शीध्र ही यह ऐसे गुप्त संगठन मे परिवर्तित हो गई जो सारे बंगाल के क्रांतिकारी कार्यकलापों को केंद्र था ',
#  'अब इस हवा को इंसुलिन की वायल में इंजेक्ट करें.सुई को अभी भी वॉयल के अंदर रखकर वॉयल को सीधी स्थिति में रखते हुए उल्टा कर दें.प्लंजर को बाहर की ओर खींचते हुए इंसुलिन की इच्छित खुराक को सिरिंज में भर लें ',
#  'एनी-की',
#  'भगवान गणेश की कहानी',
#  'संस्कृत में सिन्धु शब्द के दो मुख्य अर्थ हैं - पहला सिन्धु नदी जो मानसरोवर के पास से निकल कर लद्दाख़ और पाकिस्तान से बहती हुई समुद्र मे मिलती है दूसरा कोई समुद्र या जलराशि।',
#  'शिया इस्लाम में थोड़े अलग सिद्धांतों को स्तम्भ कहा जाता है।',
#  'इस चरण में कुछ भाग इधर उधर कर भौगोलिक और सामाजिक त्रुटि भी सुधारी गया।',
#  'नवरंग सामने एक बड़ा वर्ग बनाता हैं और उसकी बाहरी दीवारें और अधिष्ठान उसी प्रकार उभार और अतंराल और वैसे ही बाह्य अलंकरण युक़्त है ',
#  'और वे सब रिकॉर्ड करते हैं जो आप टाइप करते हैं ',
#  'अनेकों फॉण्ट परिवर्तक - वैज्ञानिक एवं तकनीकी हिन्दी समूह के फाइल सेक्शन में जावास्क्रिप्ट पर आधारित बीस से अधिक फॉण्ट परिवर्तक उपलब्ध हैं।',
#  'अपने ज्ञान को वितरित करने के लिए',
#  'किसी देश का संविधान उसकी राजनीतिक व्यवस्था का वह बुनियादी सांचा-ढांचा निर्धारित करता है जिसके अंतर्गत उसकी जनता शासित होती है ',
#  'क्या आप उसको थामे हैं',
#  'यह इसका केवल घरेलू पहलू है ',
#  'इस बाग में लिग्नाइट फुलर्सअर्थ टंगस्टन बैण्टोनाइट जिप्सम संगमरमर आदि खनिज पदार्थ प्रचुर मात्रा में पाये जाते हैं।',
#  'वेलेंटाइन आते-जाते रहेंगे , प्यार की बातें करते रहेंगे और प्यार बेचते रहेंगे लेकिन भारत को अपनी संस्कृति का कोई सौदागर नहीं चाहिए ',
#  'ढाई लाख - कम से कम इतनो के बारे में हम जानते हैं -',
#  'जल्द ही यह खबर भारत भी आ पहुंची और देश भर में आवेशपूर्ण चर्चा का विषय बन गयी ',
#  'उसका तात्कालिक आदर्श तो यही था कि वहीं बस कर संगमेश्वर की सेवा में जीवन अर्पित कर दिया जाये ',
#  'सेबी की पड़ेताल से एक चौंकाने वाली पूरी कहानी सामने आई है ',
#  'वे ढीली और जगह बदलती रहने वाली बालू पर लड़खड़ाकर गिरे बिना बहुत तेज दौड़ सकते हैं ',
#  'संभव है कि',
#  'अंग्रेज़ी हिन्दी शब्दकोष पी॰डी॰ऍफ़॰ प्रारूप में',
#  'उनके पति कुंवर भोजराज उदयपुर के महाराणा सांगा के पुत्र थे।',
#  'जो हम मर्द के तौर पर महसूस करते हैं',
#  'दिल्ली की यात्रा गांधी जी के उदार मनोभावों और रवीन्द्रनाथ के स्वास्थ्य के प्रति उनकी व्यग्रता के नाते जितना स्मरणीय रही , उतनी ही कष्टकर भी रही- ब्रिटिश सरकार के अनुदार घमंडी व्यवहार से ',
#  'लेकिन हम लोग बिलकुल ये जानते है',
#  'संदर्भ',
#  'उदाहरण के लिए, आप इसे कुछ फोन नंबर पर पा सकते हैं',
#  'कर्ण को दानवीर-कर्ण के नाम से भी जाना जाता है।',
#  'एक बार जब हमें अहसास हो गया, तब हमने निश्चय किया कि अब समय आ गया है कि हम अपनी योजना ख़ुद तैयार करें।',
#  'किसी भी विषय के बारे मे उसकी हर बात के बारे मे लिखा जाता है।',
#  'मैदान से बाहर खिलाड़ी को अपनी देख-भाल करनी चाहिए और उसे अपने आपको सौ फीसदी चुस्त और दुरूस्त रखना चाहिए ',
#  'करज़ई की अमेरिका , पाकिस्तान और खाड़ी देशों की यात्रा से संकेत मिलता है कि वे देश के पुनर्निर्माण के लिए आर्थिक मदद चाहते हैं ',
#  'इनको महाभारत में वर्णित द्वारका के सन्दर्भों से जोड़ा गया है।',
#  'लेकिन सरकार ने यह तो स्पष्ट नहीं किया था कि इलाज के बाद वे भारत कब लौट सकते हैं।',
#  'बहरहाल , अदालत ने अपराध मान लेने के कभिवचनों को स्वीकार किया और सरकारी अभियोक़्ता से कहा कि अगर वह दंड के सवाल पर कुछ कहना चाहते हैं , तो कहें ',
#  'तो मैं वापस वहाँ गया',
#  'वैज्ञानिक निष्कर्ष के प्रचार के कारन दुनिया में राजनीतिक और आर्थिक बहस चिद गई है . गरीब क्षेत्रों खासकर अफ्रीका पर बडा जोखिम दिखाई देता है जबकि उनके उत्सर्जन विकसित देशों की तुलना में काफी कम रहे हैं ',
#  'बहुत धन्यवाद आप सभी का. चलता हूँ',
#  'मुसल्मानों के अन्य देशों में प्रवास के कारण युरोप और अमरीका में भी इस्लाम फैल गया है।',
#  'वायु की गुणवत्ता मॉडलिंग',
#  'मेरा मानना है कि जनता , देश और सामाजिक सुधारों के हित में शांति बहाली जरूरी है ',
#  'विकिस्रोत से रामायण',
#  'उनकी मित्सुबिशी लंसर के बोनट पर खुरचकर मैच फिक्सर शद लिखे गए हैं , जो गाड़ी की पेंटिंग होने तक बने रहेंगे ',
#  'आपको उन बड़ी बातों के लिए अपने को तैयार करना होगा , जो आगे आयेंगी ',
#  'यह महान ऐतिहासिक दिन था ',
#  'शिक्षा',
#  'वहाँ छात्र काम करते रहेंगे',
#  'इन लोगों मैं कौन सी बात एक जैसी थी ',
#  'सौर स्थापत्य',
#  'यद्यपि महादेवी ने कोई उपन्यास कहानी या नाटक नहीं लिखा तो भी उनके लेख निबंध रेखाचित्र संस्मरण भूमिकाओं और ललित निबंधों में जो गद्य लिखा है वह श्रेष्ठतम गद्य का उत्कृष्ट उदाहरण है।',
#  'विकीपीडिया ने हज़ारों स्वेच्छा-कर्मियों के ज़रिये एक मुफ़्त विश्वकोष बना डाला',
#  'फिश टेंगा',
#  'जब आप को बेनेङिट् और मइन्टेनन्चे मिल रहा है तो आप को मिलने वाले आर्थिक सहयोग में बढती होती',
#  'साथी इमारतें',
#  'अन्य कवियों में भारतेन्दु हरिश्चन्द्र सुमित्रानन्दन पन्त और श्रीधर पाठक आदि ने भी यत्र-तत्र गंगा का वर्णन किया है।',
#  'उत्तर प्रदेश में ७० जिले हैं -',
#  'सरकार इस हेतु एकमुश्त धन और दो वर्षों तक कुछ आवर्ती राशि उपलब्ध कराती है।',
#  'वास्तव में होने वाले सुधारों से ट्रैफिक सुरक्षा के लिए सार्वजनिक नीति तैयार करने में सहायता',
#  'बच्चों में विकलांगताओं के सही स्त्रोत को',
#  'और हम बात करते हैं इस बारे में',
#  'ये सवाल इस क्षेत्र के लिए प्रासंगिक हैं क्योंकि प्रबंधन के दूसरे क्षेत्रों में वे अप्रासंगिक हो चुके हैं ',
#  'लगभग सभी ',
#  'इस प्रकार के एकाश्म स्मारक तथा स्तूप दक्षिण भारत के आंध्र तथा मैसूर के उत्तरी भागों में कई स्थलों पर प्राप्त होते है-जहां जहां मौर्य साम्राज़्य की जड़ें दक्षिण में फैली थीं अथवा जिन स्थानों पर उत्तर भारतीय धर्मों तथा बौद्ध धर्म का प्रसार था ',
#  'ट्रिब्यूनल के इस निर्णय से पूरे विश्व को धक़्का लगा क़्योंकि यह अंतर्राष्ट्रीय कानून में स्थापित शरणागत के अधिकार की हंसी उड़ाता था ',
#  'यह महानगर मुंबई शहर मुंबई उपनगर जिलों एवं नवी मुंबई तथा ठाणे शहरों को मिलाकर बनता है।',
#  'लोग जो बच्चे की देखभाल कर रहे है क्योंकि एक या फिर दोनों पालकों की मृत्यु हो गयी है ',
#  'अगर आप आँखों को मोड़े, तो आप अभी भी चेहरे देख सकते हैं।',
#  'मेरठ',
#  'ये ऐसे न्यायिक उपकरण है जिनका लक्ष्य जनहित प्राप्त करना है इनका ल्क्ष्य तीव्र तथा सस्ता न्याय एक आम आदमी को दिलवाना तथा कार्यपालिका विधायिका को उनके संवैधानिक कार्य करवाने हेतु किया जाता है',
#  'स्वयं बदरूद्दीन को अंग्रजी शिक्षा के शुरू होने से पहले ये सारी भाषाएं सीखनी पड़ी ',
#  'सबसे हुनरशुदा और युवा फोटोग्राफ़रों ने लिये हैं',
#  'राष्ट्रीय जनता दल के कार्यकारी अध्यक्ष के पद से हटाए जाने के बाद वे ललू को भगवान कृष्ण का अवतार मानने वाले यादवों के नेतृत्व पर दावा करने के लिए इस तथ्य को उछालते आ रहे हैं ',
#  'घर के नजदीक शांत सडकों पर प्रशिक्षण लिजिए ',
#  'यह इसलिये है क्योंकि पूर्णता के कई पृथक मत हैं।',
#  'करीब १००० ईसा पूर्व में छोटे-छोटे राज्य और राज्यसंगठन बनें ।',
#  'सौर विकिरणों कि',
#  'इसी के साथ साथ कंपनी ने भारतीय व्यापार और उसके उत्पादन पर एकाधिकारिक नियंत्रण प्राप्त करने के लिए अपनी राजनीतिक सत्ता का भी उपयोग किया ',
#  'ये फ्री वाई-फाई है',
#  'किंतु शीघ्र ही वह जान गए कि वह समाजवाद के अनुयायी बन गए है ',
#  'इस प्रणाली में डैटाबेस में सम्मिलित कुछ संसदीय कार्यकलापों से संबंधित आधार-सामग्री राज्य विधान मंडलों के अनुरोध पर भी उपलब्ध की जाती है ',
#  'आप ये नहीं जानते',
#  'उनका शरीर लम्बा और टांगें सुगठित तथा मजबूत , शिश्नच्छद मुड़ा हुआ और दुम छोटी होती है ',
#  'इसलिए सहज ज्ञान , सत्य और सच्चाई को ढूंढने के अन्य तरीकों को अलग नहीं रखा जा सकता ',
#  "इसके अलवा , आदिवासियों के पुराने तराशे हे घरों के संरक्षण के लिए सेनापति जिले के पुरुल गांव में ' सजीव संग्रहालय ' स्थापित किया ",
#  'हमने सारे भारत में काम किया है',
#  'बाघ की धारियों जैसी दरारों वाला यह प्रसिद्ध क्षेत्र दक्षिणी ध्रुव के आर-पार जाता है',
#  'भाजपा ने राज्य को छह भागों में बांटकर प्रत्येक को एक संग न मंत्री के हवाले कर दिया है ',
#  '२००० में उन्हें एसटीएस-१०७ में अपनी दूसरी उड़ान के कर्मचारी के तौर पर चुना गया।',
#  'भले ही कंप्यूटर असफल हो जाए',
#  'मैं और लोगों से ज्यादा उत्तेजित हूँ, एक नुएरो विज्ञानिक के तौर पे',
#  'इसके अतिरिक़्त , किसी अपराध के कारण दोषसिद्ध किया गया कोई व्यक़्ति जिसे कम से कम दो वर्षों के लिए कारावास का दंड दिया गया हो , वह व्यक़्ति अपनी रिहाई के पश्चात पांच वर्षों की अवधि के लिए अनर्ह रहता है',
#  'कि घटक कई बार गिना जाता है',
#  'भारतीय संस्कृति के मूल वेद हैं।',
#  'संविधान प्रारूप समिति तथा सर्वोच्च न्यायालय ने इस को संघात्मक संविधान माना है परन्तु विद्वानों मे मतभेद है ।',
#  'हम वहां कुछ ही प्रजातियों के जीवन की अपेक्षा कर सकते हैं ',
#  'वो शुरुआत का झटका भी नहीं था',
#  'जो डरबन के बाहर एक स्कुँत्टर शिविर से आया था',
#  'वे सारी रात बैठे और सुबह उन्हे पूरा ज्ञान प्राप्त हो गया।',
#  'यह रीति-रिवाजों पर आधारित सरल लोकतंत्र का स्वरूप है',
#  'और गणित पर ही',
#  'और बज़ूका बबलगम जैसी अच्छी और दुर्लभ चीजों',
#  'और मैं यह अक्सर करती हूँ',
#  'पहले भारत ने अपने सीमापार क्षेत्रों से काफी संख़्या में रबड़ का आयात किया था ',
#  'सन १९८० के साल में',
#  'वास्तविक निर्माण मोहक रूप से नियमित और लयबद्ध होता है.मादा अपने शरीर को लोलक की तरह दांए और बाएं घुमाते हुए पंक गुटिका को पहले एक तरफ और फिर दूसरी तरफ लगती है ',
#  'ऊष्ण-कटिबंधीय क्षेत्र में दीमक भूमि के स्वरूप और दृढ़ता को उसी प्रकार बनाए रखने में सहायता करती है , जैसे कि ब्रिटेन में केंचुआ करता है ',
#  'कैजन और कुछ नहीं बल्कि खास तरह की प्रबंधन शैली है ',
#  'विश्व के १०० सर्वोच्च शिखरों में हिमालय की अनेक चोटियाँ हैं।',
#  'उन मामलों के बारे में शिकायत जो कि आप न्यायालय में करने जा रहें हैं या करने की मंशा रखते हैं',
#  'इस बारे में कि अब क्या करें और क्या कदम उठाएं',
#  'हालंकि सेल्वम फिलहाल पान बनाकर खाने मैं व्यस्त हौं जिसे शायद क्षमा किया जा सकता है.लेकिन पान दबाते ही वे नए प्रशिक्षण-प्रदर्शन के लिए तैयार हो जाएंगे ',
#  'देशी उद्योगों की बरबादी और रोजगार के अन्य साधनों के अभाव में लाखों की संख्या में करीगर खेती की ओर तेजी से मुड़े ',
#  'जिस आदमी का निधन हुआ है उस के मालमत्ता से ञुनेरल् फय्मेन्ट्स् लिया जाता है',
#  'इसके भाद उन्हें सामान्यतया एक ३-वर्षीय स्नातक पाठ्यक्रम अपने चुने क्षेत्र में कर ना होता है जैसे विधि अभियांत्रिकी या चिकित्सा इत्यादि।',
#  'मुख्य आरोग्य अधिकारी से सब को एक वैयक्तिक सलाह',
#  'दिल्ली के सुल्तानों और मुगल बादशाहों ने इसके साथ छेड़खानी करना लाभप्रद और व्यावहारिक नहीं समझा और उन्हें पहले की तरह अपना काम करने दिया ',
#  'उसके पास पूर्ण रूप से सही स्मरणशक्ति है',
#  'मिशनरी पोजीशन',
#  'आकरे की दो टूक बातों से उत्साहित होकर शिवसैनिकों ने आम लगों को बार-बार आतंकित किया है और मुंबई की शांत , महानगरीय छवि को चोट फंचाई',
#  'दायें-से-बायें क्रम का उपयोग तुकान्त शब्दों को पास-पास लाने के लिया किया जाता है।',
#  'कब्रों को घेरे हुए जाली की दीवार',
#  'भोपाल घोषणापत्र के पीछे मुय प्रेरणा दलित लेखक चंद्रभान प्रसाद हैं ',
#  'एक नए राजनेता का चुनाव करते हैं -',
#  'और पांच गोबोट. और यही उसका खजाना था',
#  'उसने गलती से अर्नेस्ट डे नामक एक व्यापारी को मार डाला।',
#  'भाग्य',
#  ...]

# %%
transformer.train()
transformer.to(device)
total_loss = 0
num_epochs = 10

for epoch in range(num_epochs):
    print(f"Epoch: {epoch}")
    for batch_num, batch in enumerate(train_loader):
        eng_batch, hin_batch = batch
        encoder_self_attention_mask, decoder_self_attention_mask, decoder_cross_attention_mask = create_masks(eng_batch, hin_batch)
        optim.zero_grad()
        hin_predictions = transformer(eng_batch,
                                     hin_batch,
                                     encoder_self_attention_mask.to(device), 
                                     decoder_self_attention_mask.to(device), 
                                     decoder_cross_attention_mask.to(device),
                                     enc_start_token=False,
                                     enc_end_token=False,
                                     dec_start_token=True,
                                     dec_end_token=True)
        labels = transformer.decoder.sentence_embedding.batch_tokenize(hin_batch, start_token=False, end_token=True)
        loss = criterian(
            hin_predictions.view(-1, HINDI_VOCAB_SIZE).to(device),
            labels.view(-1).to(device)
        ).to(device)
        valid_indicies = torch.where(labels.view(-1) == hindi_to_index[PADDING_TOKEN], False, True)
        loss = loss.sum() / valid_indicies.sum()
        loss.backward()
        optim.step()
        #train_losses.append(loss.item())
        if batch_num % 100 == 0:
            print(f"Iteration {batch_num} : {loss.item()}")
            print(f"English: {eng_batch[0]}")
            print(f"Kannada Translation: {hin_batch[0]}")
            kn_sentence_predicted = torch.argmax(hin_predictions[0], axis=1)
            predicted_sentence = ""
            for idx in kn_sentence_predicted:
              if idx == hindi_to_index[END_TOKEN]:
                break
              predicted_sentence += index_to_hindi[idx.item()]
            print(f"Kannada Prediction: {predicted_sentence}")


            transformer.eval()
            kn_sentence = (START_TOKEN)
            eng_sentence = ("How are you",)
            for word_counter in range(MAX_SEQUENCE_LENGTH):
                encoder_self_attention_mask, decoder_self_attention_mask, decoder_cross_attention_mask= create_masks(eng_sentence, kn_sentence)
                predictions = transformer(eng_sentence,
                                          kn_sentence,
                                          encoder_self_attention_mask.to(device), 
                                          decoder_self_attention_mask.to(device), 
                                          decoder_cross_attention_mask.to(device),
                                          enc_start_token=False,
                                          enc_end_token=False,
                                          dec_start_token=True,
                                          dec_end_token=False)
                next_token_prob_distribution = predictions[0][word_counter] # not actual probs
                next_token_index = torch.argmax(next_token_prob_distribution).item()
                next_token = index_to_hindi[next_token_index]
                kn_sentence = (kn_sentence[0] + next_token, )
                if next_token == END_TOKEN:
                  break
            
            print(f"Evaluation translation (should we go to the mall?) : {kn_sentence}")
            print("-------------------------------------------")
# Out:
# Epoch: 0
# Iteration 0 : 4.3825883865356445
# English: politicians do not have permission to do what needs to be done.
# Kannada Translation: राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह करने कि अनुमति नहीं है
# Kannada Prediction:       क          क क                                                 -                               क     ििेे     ि               ॶ   क       ििकिा                ा                                        क                               ७ेेटके   े                                  े  े
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[48], line 49
#      47 for word_counter in range(MAX_SEQUENCE_LENGTH):
#      48     encoder_self_attention_mask, decoder_self_attention_mask, decoder_cross_attention_mask= create_masks(eng_sentence, kn_sentence)
# ---> 49     predictions = transformer(eng_sentence,
#      50                               kn_sentence,
#      51                               encoder_self_attention_mask.to(device),
#      52                               decoder_self_attention_mask.to(device),
#      53                               decoder_cross_attention_mask.to(device),
#      54                               enc_start_token=False,
#      55                               enc_end_token=False,
#      56                               dec_start_token=True,
#      57                               dec_end_token=False)
#      58     next_token_prob_distribution = predictions[0][word_counter] # not actual probs
#      59     next_token_index = torch.argmax(next_token_prob_distribution).item()
#
# File c:\Users\sanat\.conda\envs\ds\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\material\Machine_Deep\github_repos\AI_\AI\DL\Generative\English_to_Hindi\transformer.py:304, in Transformer.forward(self, x, y, encoder_self_attention_mask, decoder_self_attention_mask, decoder_cross_attention_mask, enc_start_token, enc_end_token, dec_start_token, dec_end_token)
#     293 def forward(self,
#     294             x,
#     295             y,
#    (...)
#     301             dec_start_token=False, # We should make this true
#     302             dec_end_token=False): # x, y are batch of sentences
#     303     x = self.encoder(x, encoder_self_attention_mask, start_token=enc_start_token, end_token=enc_end_token)
# --> 304     out = self.decoder(x, y, decoder_self_attention_mask, decoder_cross_attention_mask, start_token=dec_start_token, end_token=dec_end_token)
#     305     out = self.linear(out)
#     306     return out
#
# File c:\Users\sanat\.conda\envs\ds\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\material\Machine_Deep\github_repos\AI_\AI\DL\Generative\English_to_Hindi\transformer.py:267, in Decoder.forward(self, x, y, self_attention_mask, cross_attention_mask, start_token, end_token)
#     266 def forward(self, x, y, self_attention_mask, cross_attention_mask, start_token, end_token):
# --> 267     y = self.sentence_embedding(y, start_token, end_token)
#     268     y = self.layers(x, y, self_attention_mask, cross_attention_mask)
#     269     return y
#
# File c:\Users\sanat\.conda\envs\ds\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\material\Machine_Deep\github_repos\AI_\AI\DL\Generative\English_to_Hindi\transformer.py:75, in SentenceEmbedding.forward(self, x, start_token, end_token)
#      73 x = self.embedding(x)
#      74 pos = self.position_encoder().to(get_device())
# ---> 75 x = self.dropout(x + pos)
#      76 return x
#
# RuntimeError: The size of tensor a (301) must match the size of tensor b (300) at non-singleton dimension 1
