# %%
from train import *
from model import *
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def count_params(model):
    return sum(map(lambda p: p.data.numel(), model.parameters()))

total_param = 0
for model in [gen_a, gen_b, disc_a, disc_b]:
    total_param += count_params(model=model)

print(total_param)
# Out:
# 1561724

# %%
with torch.no_grad():
    a, b, = next(iter(dataloader))
    out_a = gen_a(a)
    out_b = gen_b(b)


plt.subplot(221)
a = a[0]
plt.imshow(a.detach().permute(1, 2, 0))


plt.subplot(222)
b = b[0]
plt.imshow(b.detach().permute(1, 2, 0))


plt.subplot(223)
out_a = out_a[0]
plt.imshow(out_a.detach().permute(1, 2, 0))


plt.subplot(224)
out_b = out_b[0]
plt.imshow(out_b.detach().permute(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
N_EPOCHS = 200

n_epochs = 1
train(n_epochs=N_EPOCHS,
      dataloader=dataloader,
      loss_fn=loss_fn,
      gen_a=gen_a,
      gen_b=gen_b,
      disc_a=disc_a,
      disc_b=disc_b,
      gen_opt_a=gen_opt_a,
      gen_opt_b=gen_opt_b,
      disc_opt_a=disc_opt_a,
      disc_opt_b=disc_opt_b,
      device=device,
      )
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# d:\material\Machine_Deep\Deep Learning\code\Specialization\Gan's\mine\CycleGan\main_testing.ipynb Cell 4 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/d%3A/material/Machine_Deep/Deep%20Learning/code/Specialization/Gan%27s/mine/CycleGan/main_testing.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> N_EPOCHS = 200
#       <a href='vscode-notebook-cell:/d%3A/material/Machine_Deep/Deep%20Learning/code/Specialization/Gan%27s/mine/CycleGan/main_testing.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> n_epochs = 1
# ----> <a href='vscode-notebook-cell:/d%3A/material/Machine_Deep/Deep%20Learning/code/Specialization/Gan%27s/mine/CycleGan/main_testing.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> train(n_epochs=N_EPOCHS,
# ...

# %%
with torch.no_grad():
    a, b, = next(iter(dataloader))
    out_a = gen_a(a)
    out_b = gen_b(b)


plt.subplot(221)
a = a[0]
plt.imshow(a.detach().permute(1, 2, 0))


plt.subplot(222)
b = b[0]
plt.imshow(b.detach().permute(1, 2, 0))


plt.subplot(223)
out_a = out_a[0]
plt.imshow(out_a.detach().permute(1, 2, 0))


plt.subplot(224)
out_b = out_b[0]
plt.imshow(out_b.detach().permute(1, 2, 0))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# d:\material\Machine_Deep\Deep Learning\code\Specialization\Gan's\mine\CycleGan\main_testing.ipynb Cell 5 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/d%3A/material/Machine_Deep/Deep%20Learning/code/Specialization/Gan%27s/mine/CycleGan/main_testing.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> with torch.no_grad():
#       <a href='vscode-notebook-cell:/d%3A/material/Machine_Deep/Deep%20Learning/code/Specialization/Gan%27s/mine/CycleGan/main_testing.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a>     a, b, = next(iter(dataloader))
# ----> <a href='vscode-notebook-cell:/d%3A/material/Machine_Deep/Deep%20Learning/code/Specialization/Gan%27s/mine/CycleGan/main_testing.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a>     out_a = gen_a(a)
# ...
